# %% [markdown]
# # Fakultät für Physik
#
# ## Physikalisches Praktikum P2 für Studierende der Physik
#
# Versuch **H24** (Stand: **April 2026**)
#
# [Raum F2-19](https://labs.physik.kit.edu/img/Klassische-Praktika/Lageplan_P2.png)
#
#
#
# # [Gammaspektroskopie](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Gammaspektroskopie/README.md)

# %% [markdown]
# Name: __________________ Vorname: __________________ E-Mail: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Name: __________________ Vorname: __________________ E-Mail: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Gruppennummer: _____
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
#
# Betreuer: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Versuch durchgeführt am: __________________

# %% [markdown]
# ---
#
# **Beanstandungen zu Protokoll Version _____:**
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# \end{split}
# %\text{\vspace{10cm}}
# \end{equation*}
#
# <br>
# Testiert am: __________________ Testat: __________________

# %% [markdown]
# # Durchführung

# %% [markdown]
# ℹ️ **Detaillierte Kommentare zur Durchführung der Aufgaben finden Sie in der Datei [Gammaspektroskopie_Hinweise.ipynb](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Gammaspektroskopie/Gammaspektroskopie_Hinweise.ipynb)**

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 1: Einrichten der Apparatur
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.1: Beschreibung der Messanordnung
#
#  * **Beschreiben Sie die Messanordnung**, die Sie für diesen Versuch vorfinden in eigenen Worten.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.2: Verwendung des Vielkanalanalysators als Oszilloskop
#
#  * Untersuchen Sie das Signal eines beliebigen radioaktiven Präparats.
#  * Verwenden Sie hierzu den **Vielkanalanalysator (Multichannel Analyzer, MCA) als Oszilloskop**.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.3: Verwendung des Vielkanalanalysators zur Bestimmung von Pulshöhenspektren
#
#  * Untersuchen Sie zur Vorbereitung auf **Aufgabe 2** die **Pulshöhenspektren der Präparate** $_{\hphantom{0}55}^{137}\mathrm{Cs},\,_{27}^{60}\mathrm{Co},\ _{11}^{22}\mathrm{Na}$.
#  * Verwenden Sie hierzu den MCA in seiner eigentlichen Eigenschaft als Pulshöhenanalysator.
#  * Bestimmen Sie einen **einheitlichen dynamischen Bereich des MCA** mit dem Sie alle folgenden Spektren aufzeichnen werden.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 2: Charakterisierung der Pulshöhenspektren verschiedener Präparate
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.1: Bestimmung des Untergrunds ohne Präparat
#
#  * Führen Sie eine **Messung ohne Präparat** durch, um ein Spektrum des Untergrunds zu erhalten, der jeder weiteren Messung unterliegt.
#  * Dokumentieren Sie die Zeitspanne, in der Sie das Spektrum aufgenommen haben.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.2: Pulshöhenspektren verschiedener Präparate
#
#  * Analysieren Sie die Impulshöhenspektren der Präparate $_{\hphantom{0}55}^{137}\mathrm{Cs}$, $_{27}^{60}\mathrm{Co}$ und $_{11}^{22}\mathrm{Na}$.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.3: Energie-Kalibration des Detektors
#
#  * Kalibieren Sie mit Hilfe der in **Aufgabe 2.2** aufgezeichneten Pulshöhenspektren die Kanäle des MCA auf die Energie $E_{\gamma}$ des einfallenden Photons.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.4: Relative Energie-Auflösung des Detektors
#
#  * Bestimmen Sie mit Hilfe der in **Aufgabe 2.2** aufgezeichneten Spektren die relative Energieauflösung des Detektors als Funktion von $E_{\gamma}$.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 3: Detektorakzeptanz
#
#  * Bestimmen Sie die Rate aufgezeichneter Photonen für $_{\hphantom{0}55}^{137}\mathrm{Cs}$ bei fünf verschiedenen Abständen des Präparats von der Detektorstirnfläche.
#  * Schätzen Sie ab und begründen Sie, ob eine Korrektur auf den unterliegenden Untergrund notwendig ist.
#  * Schätzen Sie ab und begründen Sie, ob eine Korrektur des Detektors auf pile-up notwendig ist.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Freiwillige Zusatzaufgabe: Das unbekanntes Präparat
#
# Wir haben in der Bleiburg des Praktikums eine Anzahl im Handel frei erhältlicher unbekannter Proben für Sie hinterlegt. Wenn Sie möchten können Sie ein Gammaspektrum der ein oder anderen Probe aufnehmen und versuchen herauszufinden welche (schwach strahlenden) Präparate darin enthalten sind. Dokumentieren Sie die aufgenommenen Spektren und Ihre Vermutungen in Ihrem Protokoll.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# # Beurteilung

# %% [markdown]
#  * Beurteilen Sie diesen Versuch nach Abschluss der Auswertung.
#  * **Folgen Sie zur Beurteilung dieses Versuchs diesem [Link](https://www.empirio.de/s/rGFccbHVlv)**.
#  * Beachten Sie, dass jede:r Studierende nur einmal pro Versuch eine Beurteilung abgeben kann.

# %% [markdown]
# **Lösung:**
#
# Fügen Sie Ihrem Protokoll einen Screenshot der letzten Informationsseite der oben verlinkten Beurteilung zu.
