# %% [markdown]
# # Hinweise zum Versuch **Interferenz**

# %% [markdown]
# ## Aufgabe 1: Newtonsche Ringe
#
# ---
#
# Hinweise zur Untersuchung der **Newtonschen Ringe** finden Sie in der Datei [Hinweise-Newtonringe](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/doc/Hinweise-Newtonringe.md).
#
# ---

# %% [markdown]
# ### Aufgabe 1.1 Krümmungsradius $R$ einer ausgewählten Linse

# %% [markdown]
# Machen Sie sich bevor Sie mit **Aufgabe 1.1** beginnen zunächst mit dem bereitgestellten **Stereo-Zoom-Mikroskopen** vertraut. Je besser Sie sich mit den bereitgestellten optischen Geräten zurechtfinden, desto besser und schneller können Sie die Versuche durchführen.
#
# **Hinweise zum Ablauf:**
#
#  * Wählen Sie eine geeignete Linse aus. Positionieren Sie diese auf einem Objektträger auf dem verschiebbaren Objekttisch des Mikroskops.
#  * Verwenden Sie für die gesamte **Aufgabe 1** dann immer die selbe Linse.
#  * Als Auflichtquelle dient eine einfarbige LED-Leuchte, deren Licht von vorn über einen um $45^{\circ}$ gedrehten halbdurchlässigen Strahlteiler eingekoppelt wird.
#  * Bestimmen Sie die **Durchmesser $d_{k}=2r_{k}$ so vieler Newtonscher Ringe wie möglich**.
#    * Verwenden Sie hierzu die Skala mit [Nonius](https://de.wikipedia.org/wiki/Nonius) auf dem Objekttisch und nicht die Skala des Fadenkreuzes, das in der Brennebene des Objektivs abgebildet wird.
#    * Schätzen Sie entsprechende Unsicherheiten $\Delta d_{k}$ ab.
#    * In manchen Fällen können Sie Newtonsche Ringe bis zur Ordnung $k=30$ beobachten!
#  * **Führen Sie die Messung erst mit der gelben, dann mit der blauen LED-Leuchte durch.**
#
# **Hinweise zur Auswertung:**
#
#  * Beschreiben Sie Ihr Vorgehen.
#  * Tragen Sie die ermittelten Werte $d_{k}$ geeignet gegen $k$ auf und bestimmen Sie durch Anpassung des Modells aus **Gleichung (4) [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/doc/Hinweise-Newtonringe.md)** $R\pm\Delta R$.
#    * Sie können entsprechende Werte für $\lambda$ aus dem [Datenblatt](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/Datenblatt.md) zum Versuch entnehmen.
#    * Für eine **gleichzeitige Anpassung an die Messreihen zu beiden LED-Farben** können Sie die Option [`MultiFit`](https://kafe2.readthedocs.io/en/latest/parts/beginners_guide.html#multifit) in kafe 2, wie z.B. [hier](https://gitlab.kit.edu/kit/etp-lehre/p1-praktikum/students/-/blob/main/Geometrische_Optik/doc/Hinweise-Aufgabe-2-b.md) beschrieben verwenden.
#    * Fügen Sie Ihrer Auswertung den $\chi^{2}$-Wert der Anpassung normiert auf die Freiheitgrade der Anpassung zu.

# %% [markdown]
# ### Aufgabe 1.2 Brechungsindex $n(\mathrm{H_{2}O})$ von Wasser

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Fügen Sie bei ansonsten unveränderten Bedingungen **einen Tropfen Wasser zwischen Linse und Objekträger und wiederholen Sie die Messung aus Aufgabe 1.1 für eine der beiden LED-Leuchten**.
#  * Verwenden Sie eine Farbe, die Sie auch für **Aufgabe 1.1** verwendet haben!
#  * Durch die höhere optische Dichte $n(\mathrm{H_{2}O})$ von Wasser verändern sich die Abstände $d_{k}$.
#
# **Hinweise zur Auswertung:**
#
#  * Beschreiben Sie Ihr Vorgehen.
#  * Tragen Sie für Ihre Auswertung die Wertepaare $(d_{k}, k)$ in das gleiche Diagramm, wie für die entsprechende Farbe in **Aufgabe 1.1** ein.
#  * Fügen Sie eine entsprechende Anpassung an die Messwerte zu und bestimmen Sie $n(\mathrm{H_{2}O})$.
#    * Hierzu müssen Sie das Modell aus **Aufgabe 1.1** entsprechend modifizieren.
#  * Die genaueste Bestimmung von $n(\mathrm{H_{2}O})$ erhalten Sie aus einer **gleichzeitigen Anpassung der Modelle für die Aufgaben 1.1 und 1.2** z.B. an beide Messungen mit der gleichen Farbe der LED-Leuchte, mit Hilfe der Option [`MultiFit`](https://kafe2.readthedocs.io/en/latest/parts/beginners_guide.html#multifit) in kafe 2.
#    * Beachten Sie in diesem Fall, dass in dem entsprechenden Modell $\lambda$ und $R$ in beiden **Aufgaben 1.1 und 1.2** gleich anzunehmen sind! Für die zusätzliche Konstante $C$ ist dies aber nicht zwingend der Fall.
#    * Fügen Sie Ihrer Auswertung den $\chi^{2}$-Wert der Anpassung normiert auf die Freiheitgrade der Anpassung zu.

# %% [markdown]
# ### Aufgabe 1.3 Brechungsindex $n_{L}$ der verwendeten Linse

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Zur Bestimmung des Brechungsindex $n_{L}$ der Linse fehlt Ihnen nun noch die **Kenntnis der Brennweite $f$ der Linse**.
#  * Bestimmen Sie diese mit einem Aufbau zur **Autokollimation**, wie [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/doc/Hinweise-Newtonringe.md) beschrieben.
#  * Schätzen Sie die Unsicherheit $\Delta f$ auf die Brennweite $f$ geeignet ab.
#
# **Hinweise zur Auswertung:**
#
#  * Beschreiben Sie Ihr Vorgehen.
#  * Diskutieren Sie ob $\Delta R$ oder $\Delta f$ die Unsicherheit auf $\Delta n_{L}$ dominiert.
#  * Bestimmen Sie $n_{L}\pm\Delta n_{L}$.
#  * Vergleichen Sie Ihre Ergebnisse mit der **optischen Dichte von Glas** und ähnlichen Materialien und schätzen Sie ein, ob Ihnen das erzielte Ergebnis plausibel erscheint.

# %% [markdown]
# ## Aufgabe 2: Messungen mit dem Gitterspektrometer
#
# ---
#
#  * Hinweise zur **Interferenz und Beugung am Gitter** finden Sie in der Datei [Hinweise-Gitter](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/doc/Hinweise-Gitter.md).
#  * Hinweise zum **Gitterspektrometer** selbst finden Sie in der Datei [Hinweise-Gitterspektrometer](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/doc/Hinweise-Gitterspektrometer.md).
#
# ---

# %% [markdown]
# ### Aufgabe 2.1: Justierung der Apparatur

# %% [markdown]
# **Hinweise zum Ablauf:**
#
# Eine genaue Beschreibung der Justierung mit zahlreichen Illustrationen finden Sie in den [Datenblättern zur Apparatur](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/tree/main/Interferenz/doc/Leybold-Versuch-Gitterspektrometer.pdf). Eine Kurzform der Anleitung ist im Folgenden wiedergegeben:
#
#  * Einstellung der **Fernrohrs**:
#    * Stellen Sie die Brennweite des Fernrohres (durch Verschieben des Okulars) auf "unendlich".
#    * Sie erreichen dies, z.B. indem Sie einen **weit entfernten Gegenstand scharf einstellen**.
#    * Bei richtiger Einstellung dürfen Kopfbewegungen zu keiner parallaktischen Verschiebung eines beobachteten Details und dem Fadenkreuz führen.
#    * Normalsichtige beobachten mit entspanntem (d.h. auf "unendlich" gerichtetem) Auge. Kurzsichtige können Parallellicht nicht auf die Netzhaut fokussieren und benötigen (ohne Kontaktlinse oder Brille) eine etwas abweichende Einstellung.
#  * Einstellung des **Spaltrohrs**:
#    * Beleuchten Sie den Spalt mit der Na-Spektrallampe.
#    * Beobachten Sie den **schmal eingestellten Spalt durch das Fernrohr**.
#    * Stellen Sie ihn durch Verschieben des Spaltes scharf und bringen Sie ihn dann durch Schwenken des Fernrohres **mit dem Fadenkreuz zur Deckung**.
#    * Stellen Sie den Spektrometertisch mit Teilkreis geeignet ein (Nullstellung) und arretieren Sie ihn.
#  * Einstellung der **Gitterposition**:
#    * Setzen Sie den **Spiegel in den Gitterhalter** ein (verwenden Sie hierzu einen weit geöffneten Spalt).
#    * Stellen Sie zwischen Spalt und Lampe einen **Objektträger unter $45^{\circ}$ gegen die Achse aus Spalt- und Fernrohr gedreht auf**, so dass von der Seite her über diesen "Strahlteiler" das vom Spiegel reflektierte Licht sichtbar wird, falls es durch den Spalt zurücktrifft.
#    * Der Spiegel (und damit der Gitterhalter) ist also senkrecht zur Achse justiert. Justieren Sie ggf. am Rändelrand des Gitterhalters nach.
#    * Stellen Sie dann den Spalt wieder schmal ein.
#    * Tauschen Sie schließlich den Spiegel gegen das Gitter aus.
#
# **Hinweise zur Auswertung:**
#
#  * Dokumentieren Sie Ihr Vorgehen.
#  * Fügen Sie der Auswertung eine Photographie der justierten Apparatur bei.

# %% [markdown]
# ### Aufgabe 2.2: Bestimmung der Gitterkonstanten $g$

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Verwenden Sie das **Gitter mit ${\approx}600\ \mathrm{mm^{-1}}$**.
#    * Das Verhältnis zwischen Spaltbreite und Spaltabstand beträgt $b/g\approx0.9$.
#    * Die Breite des Gitters ist mit $36\ \mathrm{mm}$ genügend groß, so dass Sie den ganzen Querschnitt des Parallellichtbündels im Spektrometer ausnutzen können.
#   * Beachten Sie, dass die **Angabe der Gitterkonstsanten nur ungefähr** ist. Es ist Bestandteil dieser Aufgabe den genauen Wert der Gitterkonstanten zu bestimmen.
#  * Beantworten Sie **zur Vorbereitung auf diese Messung** die folgenden Fragen und fügen SIe die Antworten Ihrer Auswertung zu:
#    1. Unter welchen Winkeln erwarten Sie die Hauptmaxima?
#    2. Werden diese u.U. durch Minima des Beugungsbilds am Einzelspalt ausgelöscht?
#    3. Welche Breite erwarten Sie für die Maxima?
#    4. Welches Intensitätsverhältnis erwarten Sie für die Maxima?
#    5. Mit welcher Breite müssen Sie das Gitter beleuchten, um die Na-D-Linie auflösen zu können?
#  * Nutzen Sie zur Messung das **Licht der Na-Spektrallampe**.
#  * Bestimmen Sie **so viele Messwerte $(\alpha_{m},m)$ wie möglich**, wobei $\alpha_{m}$ der Winkel des Maximums zur Ordnung $m$ ist.
#
# **Hinweise zur Auswertung:**
#
#  * Beschreiben Sie Ihr Vorgehen.
#  * Legen Sie für Ihre Messungen die **mittlere Wellenlänge $\langle \lambda\rangle=589.3\ \mathrm{nm}$** der Doppellinie des Na-Spektrums zugrunde. Die Ausmessung des Abstands $\delta\lambda$ der beiden Linien, die sich dahinter verbergen ist, **Aufgabe 2.3** vorbehalten.
#  * Nehmen Sie für $\lambda$ eine geeignete Unsicherheit $\Delta \lambda$ an.
#  * Fügen Sie Ihrer Auswertung eine graphische Darstellung der **erwarteten Intensitätsverteilung** des gelben Lichts der Na-D-Linie zu. Sie können dabe vom Skript `lattice.py` [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/tools/lattice.py) ausgehen.
#  * Tragen Sie den Sinus der Winkel $\sin\alpha_{m}$ gegen die Ordnungen $m$ der Maxima auf und passen Sie ein geeignetes Modell nach **Gleichung (2) [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/doc/Hinweise-Gitter.md)** an die Messpunkte an.
#  * Bestimmen Sie aus der Anpassung die Gitterkonstante $g\pm\Delta g$.
#  * Fügen Sie Ihrer Auswertung den $\chi^{2}$-Wert normiert auf die Freiheitgrade aus der Anpassung zu.

# %% [markdown]
# ### Aufgabe 2.3: Vermessung der Na-D-Linie

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Versuchen Sie ausgehend von **Aufgabe 2.2** nun die Na-D-Linie aufzulösen.
#  * Es kann sein, dass Sie hierzu die Breite $d$ des Spalts am Spaltrohr **nachjustieren müssen, um die Auflösung der Apparatur zu erhöhen** (siehe [Hinweise zum Gitterspektrometer](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/doc/Hinweise-Gitterspektrometer.md)).
#  * **Dokumentieren Sie den Wert von $d$** für den Sie die beste Auflösung erhalten.
#
# **Hinweise zur Auswertung:**
#
#  * Beschreiben Sie Ihr Vorgehen.
#  * Verwenden Sie für die Berechnung von $\delta\lambda$ den in **Aufgabe 2.2** gemessenen Wert von $g\pm\Delta g$.
#  * Bestimmen daraufhin $\delta\lambda\pm\Delta\delta\lambda$.
#  * Beurteilen Sie die Übereinstimmung mit Ihrer Erwartung aus den Angaben [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/doc/Hinweise-Gitterspektrometer.md).

# %% [markdown]
# ### Aufgabe 2.4: Bestimmung der Gitterkonstanten $g'$ eines zweiten Gitters

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#   * Verwenden Sie das Gitter mit ${\approx}140\ \mathrm{mm^{-1}}$.
#   * Beachten Sie, dass die **Angabe der Gitterkonstsanten nur ungefähr** ist. Es ist Bestandteil dieser Aufgabe den Wert der Gitterkonstanten zu bestimmen.
#   * Verwenden Sie als Lichtquelle die **Na-Spektrallampe**.
#   * Gehen Sie ansonsten wie für **Aufgabe 2.2** vor.
#
# **Hinweise zur Auswertung:**
#
#  * Beschreiben Sie Ihr Vorgehen.
#  * Tragen Sie jeweils den Sinus der Winkel $\sin\alpha_{m}$ aller beobachtbaren Maxima gegen die Ordnung $m$ der Maxima auf und passen Sie ein geeignetes Modell an.
#  * Gehen Sie dabei, wie in **Aufgabe 2.2** vor.
#  * Bestimmen aus der Anpassung die Gitterkonstante $g'\pm\Delta g'$.
#  * Fügen Sie Ihrer Auswertung den $\chi^{2}$-Wert normiert auf die Freiheitgrade aus der Anpassung zu.
#  * Beantworten Sie in Ihrer Auswertung die folgenden Fragen:
#    1. Das Gitter kann bis bis zu 6. Ordnung mit monoton abnehmender Intensität in jeder Ordnung beobachtet werden. Was lässt sich aus dieser Beobachtung über $b$ schlussfolgern?
#    2. Von welcher Ordnung ab ist die Na-D-Linie getrennt beobachtbar?
#    3. Ist Ihre Beobachtung konsistent mit dem erwarteten Auflösungsvermögen?

# %% [markdown]
# ### Aufgabe 2.5: Linienspektrum der Zn-Spektrallampe

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Wählen sie ein geeignetes Gitter aus; begründen und dokumentieren Sie Ihre Wahl.
#  * Bestimmen Sie zu jeder Wellenlänge $\lambda_{i}$ die Winkel $\alpha_{m}$ der Maxima so vieler Ordnungen $m$ wie möglich.
#
# **Hinweise zur Auswertung:**
#
#  * Beschreiben Sie Ihr Vorgehen.
#  * Tragen Sie jeweils den Sinus der Winkel $\sin\alpha_{i,m}$ aller beobachtbaren Maxima gegen die Ordnung $m$ der Maxima auf und passen Sie ein geeignetes Modell zur Bestimmung von $\lambda_{i}\pm\Delta\lambda_{i}$ an.
#  * Verwenden Sie hierzu den **entsprechenden Wert der Gitterkonstanten**, wie durch Ihre zuvorigen Messungen bestimmt.
#  * Fügen Sie Ihrer Auswertung den $\chi^{2}$-Wert normiert auf die Freiheitgrade aus der Anpassung zu.
#  * **Vergleichen Sie Ihre Ergebnisse** im Rahmen der ermittelten Unsicherheiten mit Ihrer Erwartung aus den Angaben [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Interferenz/doc/Hinweise-Gitterspektrometer.md).
