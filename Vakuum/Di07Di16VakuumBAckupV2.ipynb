# %% [markdown]
# # Fakultät für Physik
#
# ## Physikalisches Praktikum P2 für Studierende der Physik
#
# Versuch **H13** (Stand: **April 2026**)
#
# [Raum F1-15](https://labs.physik.kit.edu/img/Klassische-Praktika/Lageplan_P2.png)
#
#
#
# # [Vakuum](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Vakuum/README.md)

# %% [markdown]
# Name: __Haag__ Vorname: __Finn__ E-Mail: __uvvln@student.kit.edu__
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Name: __Trunzer__ Vorname: __Kiran__ E-Mail: __urmat@student.kit.edu__
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Gruppennummer: __Di7, Di16__
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
#
# Betreuer: __Jonathan Kley__
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Versuch durchgeführt am: __________________

# %% [markdown]
# ---
#
# **Beanstandungen zu Protokoll Version _____:**
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# \end{split}
# %\text{\vspace{10cm}}
# \end{equation*}
#
# <br>
# Testiert am: __________________ Testat: __________________

# %% [markdown]
# # Durchführung

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.1: Orientierung und Beschreibung des Versuchsaufbaus
#
#  * Verschaffen Sie sich einen Überblick über die verwendeten Apparaturen und beschreiben Sie sie in eigenen Worten.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# Die vier Hauptkomponenten des Versuchsaufbaus waren der Rezipient $RZ$, eine Turbomolekularpumpe $TMP$, eine Drehschieberpumpe $DSP$ und ein Referenzvolumen $RV$ - unten mehr zu den einzelnen Komponenten.
#
# Verbunden waren diese Hauptkomponenten über drei Ventile:
# * $V_1$ zwischen $DSP$ und $TMP$
# * $V_2$ zwischen $TMP$ und $RZ/RV$
# * $V_3$ zwischen $RV$ und $RZ$
#
# Zusätzlich waren zwei Ventile $B_1$ und $B_2$, im Aufbau verbaut, um die Apparatur zu belüften. Zwischen der $TMP$ und der $V_1$ war zudem ein austauschbares Leitungselement, welches in Aufgabe 2.2 zum Einsatz kommt. Zur Messung des Druckes standen zwei Arten von Messinstrumenten zu Verfügung. Einerseits Wärmeleitvakuummeter $ T_1 , T_2$ und $T_3$, welche mittels der druckabhängigen Wärmeleitfähigkeit des Restgases, zum Messen der höheren Drücke ab  $5\times 10^{-4} mbar$   verrwendet wird. Andererseits das Ionisationsvakuummeter, das bei Drücken bis zu $10^{-9} mbar$  verwendung kommt und durch Messung des Ionenstroms des ionisierten Restgases zu seinen Werten kommt.
#
# Die Unsicherheiten der Wärmeleitvakuummeter liegen bei:
#
# $$
# \begin{array}{c|c}
# \text{Druck p in mbar} & \text{relative Ungenauigkeit} \\ \hline
# (5\cdot10^{-4}, 10^{-3}) & \pm10\% \\
# (10^{-3},10^2) & \pm2\% \\
# (10^2,10^3) & \pm25\% \\
# \end{array}
# $$
#
# und für das Ionisationsvakuummeter bei $\pm30\%$.
#
#
# ---

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import kafe2
import pandas as pd

# %%
from os import getcwd
PWD=getcwd()

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = plt.figure("demo", figsize=(10.0, 10.0))
img = mpimg.imread('VakuumSkizze.png'.format(PWD=PWD))
imgplot = plt.imshow(img)
imgplot.axes.get_xaxis().set_visible(False)
imgplot.axes.get_yaxis().set_visible(False)
plt.title("(Abb.1) Vakuum-Skizze")
plt.show()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.2: Gasentladung (Demonstrationsversuch)
#
#  * Schalten Sie das Hochspannungsgerät zur Erzeugung der Gasentladungen ein.
#  * Evakuieren Sie den Rezipienten (RZ) und die Gasentladungsröhre mit Hilfe der Drehschieberpumpe (DSP).
#  * Senken Sie den Druck kontinuierlich, bis die Gasentladung erlischt.
#  * Beschreiben Sie die Gasentladung in Abhängigkeit vom Gasdruck.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# Dieser Versuch wurde am Versuchsaufbau 153 durchgeführt. Da dort am RZ noch eine
# Gasentladungsröhre eingebaut war.
# Für diesen Versuch wurden die Ventile V1 und V2 geöffnet und somit die DSP mit dem RZ
# verbunden.
# Zum Evakuieren wurde hier ausschließlich die DSP verwendet, weshalb die Gasentladung nur
# in einem tendenziell gröberen Vakuum untersucht wurde.
# Die Gasentladungsröhre wurde, zuerst noch bei Normaldruck, unter Spannung gesetzt.
# Innerhalb der Röhre wurden damit Elektronen beschleunigt, welche mit der in der Röhre
# befindenden Luft, größtenteils Stickstoff, stießen.
# Haben die Elektronen genug Energie, also haben sie eine gewisse Strecke im
# Beschleunigungsfeld zurückgelegt, so können die Stickstoffatome kurzzeitig angeregt
# werden, woraufhin sie sich wieder abregen und ein Photon mit einer charakteristischen
# Wellenlänge emittieren. Der Prozess wiederholt sich, während die Elektronen weiter beschleunigt werden. Die Abstände zwischen den aufeinanderfolgenden Anregungs- und Emissionsereignissen sind jedoch nicht streng äquidistant, da die Stöße statistischer Natur sind und zufällig erfolgen.
# Dies geschieht bei Normaldruck allerdings kaum bis gar nicht, da die Elektronen zu oft
# durch Stöße an Energie verlieren, bevor sie zu einer Anregung genug Energie haben.
# Wird der Druck allerdings gesenkt, so findet zuerst immer mehr Gasentladung statt, da nun
# weniger Stoßpartner vorhanden sind, die die Elektronen vorzeitig entschleunigen. Somit wird
# das beobachtbare Licht erst immer heller.
#
# ---

# %%
from os import getcwd
PWD=getcwd()

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = plt.figure("demo", figsize=(10.0, 10.0))
img = mpimg.imread("1_2.jpg".format(PWD=PWD))
imgplot = plt.imshow(img)
imgplot.axes.get_xaxis().set_visible(False)
imgplot.axes.get_yaxis().set_visible(False)
plt.title("(Abb.2) Gasentladung Stickstoff")
plt.show()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 2: Saugvermögen und Strömungsleitwert
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.1: Saugvermögen der DSP
#
# Evakuieren Sie die Apparatur mit Hilfe der DSP und stellen Sie die folgenden Größen, bestimmt aus dem **Druck bei T1**, geeignet graphisch dar:
#
#  * Das effektive Saugvermögen als Funktion des Drucks $S_{\mathrm{eff}}(p)$.
#  * Den Druck als Funktion der Zeit $p(t)$, für eine geeignete Auswahl an Messpunkten.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# In diesem Versuch sollten wir das Saugvermögen der Drehschieberpumpe (DSP) messen. Hierfür wurde die Apparatur vollständig belüftet. Anschließend wird der Druck mithilfe der Drehschieberpumpe verringert und mit der Messstation T1 für einen Zeitraum von 5 Minuten alle 5 Sekunden ein Wert gemessen. Mithilfe dieser Messwerte wird nun das Saugvermögen S(p) berechnet. Das Volumen konnten wir dem Datenblatt entnehmen, für n wählten wir den Wert $1$.
#
# $$
# S(p) =  \frac{V_{RZ}}{n(t_{i + 1} - t_i)}  ln(\frac{p_i}{p_{i+ 1}})
# $$
#
#
#
#
# ---

# %% [markdown]
# **L Ö S U N G**

# %%
p_21 = np.array([1000, 1000, 1000, 1000, 1000, 400, 150, 80, 51, 30, 20, 13.5, 9.13, 6.25, 4.27, 2.91, 2.04, 1.5, 1.14, 0.72, 0.69, 0.48, 0.37, 0.30, 0.25, 0.21, 0.185, 0.164, 0.149, 0.134, 0.125, 0.114, 0.106, 0.1, 0.0942, 0.0903, 0.0871, 0.0832, 0.08, 0.078, 0.076, 0.075, 0.073, 0.071, 0.069, 0.067, 0.065, 0.064, 0.063, 0.062, 0.061, 0.060, 0.059, 0.058, 0.057, 0.056, 0.055, 0.055, 0.054, 0.053])

t=np.arange(0, len(p_21) * 5, 5)

#Unsicherheiten
delta_p = np.zeros_like(p_21)
for i, p in enumerate(p_21):
    if 5e-4 <= p < 1e-3:
        delta_p[i] = 0.10 * p  
    elif 1e-3 <= p < 1e2:
        delta_p[i] = 0.02 * p  
    elif 1e2 <= p <= 1e3:
        delta_p[i] = 0.25 * p  
    else:
        delta_p[i] = 0.02 * p 
        

plt.yscale('log')
plt.errorbar(t, p_21, yerr=delta_p, xerr=0.0539, fmt='x', ecolor='blue', capsize=2)
plt.xlabel('Zeit (s)')
plt.ylabel('Druck (mbar)')
plt.title('Druck-Zeit Diagramm')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Stein\AppData\Local\Temp\ipykernel_7120\491934874.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
V = 10.119  
n=1

def S_p(t_i, t_ip1, p_i, p_ip1, V, n=1):
    return V/(n*(t_ip1 - t_i))*np.log(p_i/p_ip1)

S = [S_p(t[i], t[i+1], p_21[i], p_21[i+1], V, n)
     for i in range(len(p_21)-1)]


def S_err(t_i, t_ip1, p_i, p_ip1, V, n=1,
          rel_p_err=0.02,
          dt_err=0.0539):

    dt = t_ip1 - t_i

    S_val = S_p(t_i, t_ip1, p_i, p_ip1, V, n)

    # Fehler von ln(p_i/p_ip1)
    err_ln = np.sqrt(
        (rel_p_err)**2 +
        (rel_p_err)**2
    )

    rel_err = np.sqrt(
        (dt_err/dt)**2 +
        err_ln**2
    )

    return abs(S_val) * rel_err



def mean(list,start, finish):
    sum = 0
    i = 0
    for _ in range(start,finish+1):
        sum += list[_]
        i += 1
    return sum/i

Serr = [
    S_err(
        t[i],
        t[i+1],
        p_21[i],
        p_21[i+1],
        V,
        n
    )
    for i in range(len(p_21)-1)
]



plt.errorbar(x=p_21[:-1],y=S,xerr=0.0539*np.array(p_21[:-1]), yerr=Serr, fmt='x', ls='none', capsize=3)
plt.title('Saugvermögen')
plt.xlabel('Druck in $mbar$')
plt.ylabel(r'S in $\frac{{l}}{{s}}$')
plt.xscale('log')
plt.ylim(-0.2,1.2)
plt.axvline(x=p_21[9],color="red")
plt.axvline(x=p_21[21],color="red")
plt.axhline(y=mean(list=S,start=10,finish=20),xmin=0.245,xmax=0.63,color='orange')
plt.text(x=p_21[7],y=1,s='Bereich I',fontweight='bold',fontsize='medium')
plt.text(x=p_21[18],y=1,s='Bereich II',fontweight='bold',fontsize='medium')
plt.text(x=p_21[59],y=1,s='Bereich III',fontweight='bold',fontsize='medium')

plt.show()

# %%
plt.errorbar(t[10:20],p_21[10:20],yerr=0.0539*p_21[10:20],xerr=0.196, fmt='x', ls='none')
plt.yscale('log')
plt.title('Druck-Zeit Diagramm Bereich II')
plt.xlabel(('Zeit in s'))
plt.ylabel('Druck in mbar')
plt.show()

# %%
def moddel_21(t,t_0=t[10],p_0=p_21[10],S=mean(list=S,start=10,finish=20)):
    return np.log(p_0*np.exp(-(S)/(V)*(t-t_0)))

dataset = kafe2.XYContainer(x_data=t[10:20],y_data=np.log(p_21[10:20]))
dataset.axis_labels=['Zeit in s', 'log(p) in mbar']
dataset.label='Druck-Zeit Diagramm Bereich II'
dataset.add_error(axis='x',err_val=0.196)
dataset.add_error(axis='y',err_val=0.0539,relative=True)

fit = kafe2.Fit(dataset,model_function=moddel_21)
fit.limit_parameter("t_0", lower=0)

fit.do_fit()
fit_result=kafe2.Plot([fit])

fit_result.plot()
plt.show()

# %% [markdown]
# **D I S K U S S I O N**
#
# Schaut man sich nun den zweiten Graphen an, so erkennt man, dass sich dieser in drei Bereiche einteilen lässt. Im ersten Bereich steigt das Saugvermögen an, da anfangs die Gasdichte sehr hoch ist und die Pumpe ineffizient arbeitet. Im zweiten Bereich ist das Saugvermögen konstant. Hier arbeitet die Pumpe am effektivsten. Im dritten Bereich kommt die DSP an ihre Grenzen und die Gasdichte wird sehr gering und sorgt somit dafür, dass nur noch wenige Teile in die Pumpe kommen. Schaut man sich nun den zweiten Bereich von Sekunde $45$ bis $110$ genauer an und führt diesen Fit durch $p(t)=p_0 ⋅ e^{-\frac {S}V(t−t_0)}$, so sieht man, dass vor allem am Anfang des zweiten Bereichs eine große Abweichung herscht. Dies liegt daran, dass der Fit vereinfacht ist und nicht alle realen Prozesse abbildet. Zudem können Ablesefehler zu starken Abweichungen führen.
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.2: Leitwert eines dünnen zylindrischen Rohrs
#
#  - Bereiten Sie die Apparatur darauf vor Druckmessungen vor und hinter einem am Experiment ausliegenden Metallrohr vorzunehmen.
#  - Bestimmen Sie die Drucke $p_{1}$ (**bei T1**) vor und $p_{2}$ (**bei T2**) hinter dem Rohr als Funktion der Zeit.
#  - Bestimmen Sie aus den gewonnenen Daten den Leitwert $L$ des Rohrs.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# In diesem Versuch wird nun der Metallschlauch gegen ein Metallrohr im Durchmesser von $d=3.5mm$
# Getauscht, was das Volumen verringert und den Widerstand der Pumpe erhöht.
# Hierfür wird nun der Druck zusätzlich bei dem Messpunkt T2 gemessen, welcher sich am
# gegenüberliegenden Ende des Metallrohrs zu T1 befindet. Wie bereits zuvor wird auch bei
# diesem Versuch alle 5 Sekunden über einen Zeitraum von 5 Minuten einen Messwert
# genommen.
#
#
# ---

# %% [markdown]
# **L Ö S U N G**

# %%
p_T1 = np.array([1000, 1000, 1000, 1000, 1000, 1000, 980, 540, 154, 40, 26, 16, 9, 7, 5, 4, 3.2, 2.1, 2.08, 1.77, 1.51, 1.31, 1.13, 0.996, 0.879, 0.787, 0.0701, 0.634, 5.76, 5.25, 0.478, 0.0443, 0.0410, 0.378, 0.0349, 0.327, 0.309, 0.288, 0.272, 0.253, 0.242, 0.229, 0.216, 0.207, 0.198, 0.191, 0.184, 0.173, 0.165, 0.158, 0.153, 0.147, 0.141, 0.136, 0.132, 0.128, 0.124, 0.121, 0.118])
p_T2 = np.array([1000, 1000, 1000, 1000, 1000, 1000, 960, 670, 176, 53, 28, 20, 18, 15, 12, 10, 9.2 , 7.28, 6.64, 6.00, 5.50, 5.00, 4.68, 4.35, 4.08, 3.82, 3.61, 3.41, 3.24, 3.06, 2.94, 2.80, 2.69, 2.57, 2.47, 2.39, 2.30, 2.22, 2.15, 2.08, 2.02, 1.96,1.90, 1.86, 1.81, 1.76, 1.72, 1.69, 1.64, 1.61, 1.57, 1.53, 1.51, 1.47, 1.45, 1.43, 1.40, 1.37, 1.35])
#, 0.115 
t=np.arange(0, len(p_T1) * 5, 5)

delta_T1 = np.zeros_like(p_T1)
for i, p in enumerate(p_T1):
    if 5e-4 <= p < 1e-3:
        delta_T1[i] = 0.10 * p  
    elif 1e-3 <= p < 1e2:
        delta_T1[i] = 0.02 * p  
    elif 1e2 <= p <= 1e3:
        delta_T1[i] = 0.25 * p  
    else:
        delta_T1[i] = 0.02 * p 
        
delta_T2 = np.zeros_like(p_T2)
for i, p in enumerate(p_T2):
    if 5e-4 <= p < 1e-3:
        delta_T2[i] = 0.10 * p  
    elif 1e-3 <= p < 1e2:
        delta_T2[i] = 0.02 * p  
    elif 1e2 <= p <= 1e3:
        delta_T2[i] = 0.25 * p  
    else:
        delta_T2[i] = 0.02 * p 
        


plt.yscale('log')
plt.errorbar(t ,p_T1 ,yerr=delta_T1,xerr=0.196,fmt='x',ls='none',color='blue',label='T1')
plt.errorbar(t ,p_T2,yerr=delta_T2,xerr=0.196,fmt='x',ls='none',color='green',label='T2')
plt.xlabel("Zeit [s]")
plt.ylabel("Druck [mbar]")
plt.yscale('log')
plt.title("Druck-Zeit Diagramm")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
V= 9.9054
S1 = [S_p(t[i]+20, t[i+1]+20, p_T1[i], p_T1[i+1], V) for i in range(len(p_T1)-1)]
Serr1 = [S_err(t[i]+20, t[i+1]+20, p_T1[i], p_T1[i+1], V) for i in range(len(p_T1)-1)]
S2 = [S_p(t[i]+20, t[i+1]+20, p_T2[i], p_T2[i+1], V) for i in range(len(p_T2)-1)]
Serr2 = [S_err(t[i]+20, t[i+1]+20, p_T2[i], p_T2[i+1], V) for i in range(len(p_T2)-1)]
plt.errorbar(x=p_T1[:-1],y=S1,xerr=0.0539*(p_T1[:-1]),yerr=Serr1,fmt='x', ls='none', color='blue')
plt.errorbar(x=p_T2[:-1],y=S2,xerr=0.0539*(p_T2[:-1]),yerr=Serr2, fmt='x', ls='none', color='green')
plt.title('Saugvermögen')
plt.xlabel('Druck in $mbar$')
plt.ylabel(r'S in $\frac{{l}}{{s}}$')
plt.xscale('log')
plt.ylim(-0.2,1.2)
plt.axvline(x=p_T1[17],ymin= 0.5 ,ymax= 0.65,color="red")
plt.axvline(x=p_T1[9],ymin= 0.5 ,ymax= 0.65,color="red")
plt.axhline(y=mean(list=S1,start=9,finish=17),xmin=0.41,xmax=0.66,color='orange')
plt.axvline(x=p_T2[9],ymin= 0.4 ,ymax= 0.55,color="red")
plt.axvline(x=p_T2[17],ymin= 0.4 ,ymax= 0.55,color="red")
plt.axhline(y=mean(list=S2,start=9,finish=16),xmin=0.52,xmax=0.69,color='orange')
plt.show()

# %%
def moddel_T1(t,t_0=t[9],p_0=p_T1[9],S=mean(list=S1,start=9,finish=17)):
    return np.log(p_0*np.exp(-(S)/(V)*(t-t_0)))

# Create Dataset
dataset_S1 = kafe2.XYContainer(x_data=t[9:17],y_data=np.log(p_T1[9:17]))
dataset_S1.axis_labels=['Time in s', 'log(p) in mbar']
dataset_S1.label='Druck-Zeit Diagramm für T1'

dataset_S1.add_error(axis='x',err_val=0.196)
dataset_S1.add_error(axis='y',err_val=0.0539,relative=True)
  
fit_S1 = kafe2.Fit(dataset_S1,model_function=moddel_T1)
fit_S1.limit_parameter("t_0", lower=0)
fit_S1.do_fit()
fit_result_S1=kafe2.Plot([fit_S1])
params_1=fit_S1.parameter_values
params_err_1=fit_S1.parameter_errors
fit_result_S1.plot()
plt.show()

def moddel_T2(t,t_0=t[9],p_0=p_T2[9],S=mean(list=S2,start=9,finish=16)):
    return np.log(p_0*np.exp(-(S)/(V)*(t-t_0)))

# Create Dataset
dataset_S2 = kafe2.XYContainer(x_data=t[9:16],y_data=np.log(p_T2[9:16]))
dataset_S2.axis_labels=['Time in s', 'log(p) in mbar']
dataset_S2.label='Druck-Zeit Diagramm für T2'

dataset_S2.add_error(axis='x',err_val=0.196)
dataset_S2.add_error(axis='y',err_val=0.0539,relative=True)
  
fit_S2 = kafe2.Fit(dataset_S2,model_function=moddel_T2)
fit_S2.limit_parameter("t_0", lower=0)
fit_S2.do_fit()
fit_result_S2=kafe2.Plot([fit_S2])
params_2=fit_S2.parameter_values
params_err_2=fit_S2.parameter_errors
fit_result_S2.plot()
plt.show()

# %%
S1_mean = mean(S1, start=9, finish=17)
S2_mean = mean(S2, start=9, finish=17)

L_mean = (S1_mean * S2_mean) / (S1_mean - S2_mean)
print(f"L exp aus Mittelwerten = {L_mean:.4f} l/s")
# Out:
# L exp aus Mittelwerten = 1.5373 l/s

# %% [markdown]
# **D I S K U S S I O N**
#
# Zu Beginn der Messung ist der Druck im gesamten System nahezu homogen ($  p_1 \approx p_2  $), sodass zunächst keine Druckdifferenz erkennbar ist. Durch den Strömungswiderstand des Metallrohres baut sich rasch eine Differenz $  \Delta p = p_1 - p_2  $ auf, die bei niedrigen Drücken wieder abnimmt – ein typisches Verhalten beim Übergang in den molekularen Strömungsbereich.
# Sowohl bei T1 als auch bei T2 ist ein Bereich mit annähernd konstantem Saugvermögen erkennbar. Der Gasdurchsatz $  q_{pV}  $ wurde nach der Beziehung $  q_{pV} = V \cdot |\dot{p}|  $ (für konstantes Volumen) berechnet, wobei $  \dot{p}  $ aus den Messwerten von $  p_1(t)  $ (vor dem Rohr) bestimmt wurde, da dieser den treibenden Druckgradienten physikalisch am besten repräsentiert.
# Die Leitfähigkeit des Rohres ergab sich aus $  L = q_{pV} / \Delta p  $.
# Da die direkten Fits der Saugleistungen in den Plateaubereichen teilweise starke Streuungen und Instabilitäten aufwiesen, wurde die Leitfähigkeit aus den Mittelwerten der Saugleistung im Plateau-Bereich berechnet. Diese Vorgehensweise ist robuster gegenüber einzelnen Ausreißern und Ablesefehlern.
#
# Die experimentell bestimmte Leitfähigkeit beträgt $  L_{\text{exp}} = 1{,}54\,\mathrm{l/s}  $ und liegt damit in der gleichen Größenordnung wie der theoretische Wert  im Feinvakuum von $  L_{\text{theo}} \approx 0{,}9 - 2{,}0\,\mathrm{l/s}  $.
# Der gemessene Wert stimmt qualitativ gut mit der Theorie überein. Quantitative Abweichungen sind vor allem auf Ablesefehler bei der Digitalisierung, Ungenauigkeiten bei der numerischen Ableitung $  \dot{p}  $ sowie Volumenunsicherheiten zurückzuführen. Mithilfe der Kenngröße $  d \cdot \overline{p}  $ wurde gezeigt, dass die Apparatur alle drei Strömungsbereiche durchläuft, was das beobachtete Verhalten erklärt.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.3: Betrieb der Turbomolekularpumpe (TMP)
#
#  - Nehmen Sie die TMP in Betrieb und bestimmen Sie analog zu **Aufgabe 2.1** $S_{\mathrm{eff}}(p)$ für die TMP als Funktion des Drucks, der durch das Ionisationsvakuummeter (IM) angezeigt wird.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# Im abschließenden Versuch der Aufgabe 2 wird der Rezipient zunächst mithilfe der Drehschieberpumpe auf einen Druck von $0,08 \text{mbar}$ evakuiert. Danach wird die Turbomolekularpumpe in Betrieb genommen und der Druck wird über 5 Minuten hinweg alle 5 Sekunden gemessen. Dieser zweistufige Prozess verhindert eine Überhitzung der TMP, die bei höheren Drücken auftreten würde.
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
#
#
# ---

# %%
t3_3 = np.array([0.0795, 0.0786, 0.0705, 0.0569, 0.0408, 0.0252, 0.0155, 0.00894, 0.00573, 0.00408, 0.00326, 0.00277, 0.00248, 0.00227, 0.00211, 0.00201, 0.00195, 0.00186, 0.00182, 0.00175, 0.00168, 0.00163, 0.00161, 0.00157, 0.00154, 0.00150, 0.00147, 0.00144, 0.00143, 0.00142, 0.00139, 0.00138, 0.00137, 0.00134, 0.00132, 0.00130, 0.00130, 0.00129, 0.00127, 0.00127, 0.00126, 0.00126, 0.00125, 0.00124, 0.00122, 0.00122, 0.00121, 0.00120, 0.00119, 0.00119, 0.00118, 0.00115, 0.00114, 0.00113, 0.00112, 0.00111, 0.00111, 0.00110, 0.00110, 0.00110, 0.00109])

t=np.arange(0, len(t3_3) * 5, 5)

#Unsicherheiten
delta_p = np.zeros_like(t3_3)
for i, p in enumerate(t3_3):
    if 5e-4 <= p < 1e-3:
        delta_p[i] = 0.10 * p  
    elif 1e-3 <= p < 1e2:
        delta_p[i] = 0.02 * p  
    elif 1e2 <= p <= 1e3:
        delta_p[i] = 0.25 * p  
    else:
        delta_p[i] = 0.02 * p 
        

plt.yscale('log')
plt.errorbar(t, t3_3, yerr=delta_p, xerr=0.0539, fmt='x', ecolor='blue', capsize=2)
plt.xlabel('Zeit (s)')
plt.ylabel('Druck (mbar)')
plt.title('Druck-Zeit Diagramm')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
print(len(t3_3))
# Out:
# C:\Users\Stein\AppData\Local\Temp\ipykernel_7120\507196730.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 61

# %%
V = 10.119  

def S_p(t_i, t_ip1, p_i, p_ip1, V, n=1):
    return V/(n*(t_ip1 - t_i))*np.log(p_i/p_ip1)

S = [S_p(t[i], t[i+1], t3_3[i], t3_3[i+1], V)
     for i in range(len(t3_3)-1)]



def S_err(t_i, t_ip1, p_i, p_ip1, V, n=1,
          rel_p_err=0.02,
          dt_err=0.0539):

    dt = t_ip1 - t_i

    S_val = S_p(t_i, t_ip1, p_i, p_ip1, V, n)

    # Fehler von ln(p_i/p_ip1)
    err_ln = np.sqrt(2) * rel_p_err

    rel_err = np.sqrt(
        (dt_err/dt)**2 +
        err_ln**2
    )

    return abs(S_val) * rel_err

Serr = [
    S_err(
        t[i],
        t[i+1],
        t3_3[i],
        t3_3[i+1],
        V
    )
    for i in range(len(t3_3)-1)
]


def mean(list,start, finish):
    sum = 0
    i = 0
    for _ in range(start,finish+1):
        sum += list[_]
        i += 1
    return sum/i


plt.errorbar(x=t3_3[:-1],y=S, xerr=0.0539*np.array(t3_3[:-1]), yerr =Serr, fmt='x', ls='none')

plt.title('Saugvermögen')
plt.xlabel('Druck in $mbar$')
plt.ylabel(r'$S_p$ in $\frac{{l}}{{s}}$')
plt.xscale('log')
plt.ylim(-0.2,1.2)
plt.axvline(x=t3_3[7],color="red")
plt.axvline(x=t3_3[3],color="red")
plt.axhline(y=mean(list=S,start=3,finish=7),xmin=0.5,xmax=0.87,color='orange')
plt.text(x=t3_3[2],y=1,s='Bereich I',fontweight='bold',fontsize='medium')
plt.text(x=t3_3[6],y=1,s='Bereich II',fontweight='bold',fontsize='medium')
plt.text(x=t3_3[20],y=1,s='Bereich III',fontweight='bold',fontsize='medium')
plt.show()

# %%
def moddel_23(t,t_0=t[3],p_0=t3_3[3],S=mean(list=S,start=3,finish=7)):
    return np.log(p_0*np.exp(-(S)/(V)*(t-t_0)))

dataset_T3 = kafe2.XYContainer(x_data=t[3:7],y_data=np.log(t3_3[3:7]))
dataset_T3.axis_labels=['Zeit in s', 'log(p) in mbar']
dataset_T3.label='Druck-Zeit Diagramm Bereich II'
dataset_T3.add_error(axis='x',err_val=0.196)
dataset_T3.add_error(axis='y',err_val=0.0539,relative=True)  
fit_T3 = kafe2.Fit(dataset_T3,model_function=moddel_23)
fit_T3.limit_parameter("t_0", lower=0)
fit_T3.do_fit()
fit_result_T3=kafe2.Plot([fit_T3])
params_3=fit_T3.parameter_values
params_err_3=fit_T3.parameter_errors
fit_result_T3.plot()
plt.show()

# %% [markdown]
# **D I S K U S S I O N**
#
# Die gemessene Saugleistung zeigt den für eine Turbomolekularpumpe typischen Verlauf. Im mittleren Druckbereich (Bereich II) erreicht die TMP ein nahezu konstantes Saugvermögen. Der Fit in diesem Bereich beschreibt die Daten sehr gut ($  \chi^2/\text{ndf} \ll 1  $), was auf ein weitgehend ideales exponentielles Auspumpverhalten hinweist. Die leichte systematische Abweichung am Anfang des Bereichs ist auf die noch laufende Hochlaufphase der TMP (ca. 2 Minuten) zurückzuführen. Laut Datenblatt besitzt die verwendete Turbomolekularpumpe ein nominelles Saugvermögen von $  S \geq 30\,\mathrm{l/s}  $ (bei $7200 \text{min}^{-1}$). Der experimentell bestimmte Wert von $0,87$ l/s liegt deutlich darunter. Das Verhalten ist erwartbar, da das angeschlossene Volumen für die Turbomolekularpumpe viel zu klein ist, um ihr nominelles Saugvermögen auszunutzen. Die tatsächlich erreichbare Saugleistung wird stark durch die geringe Leitfähigkeit der Verbindungsleitungen, das kleine Systemvolumen sowie den Einfluss der Vorpumpe begrenzt wird.
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 3: Einfache Experimente im Vakuum
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 3.1: Statische Kalibration von T3
#
# Führen Sie mit Hilfe des Referenzvolumes RV eine statische Kalibration des Vakuummeters T3 durch.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# Zur Kalibration des Vakuummeters T3 wird ein einstufiges statisches Kalibrationsverfahren mit dem Referenzvolumen $RV$ durchgeführt. Grundlage ist das Boyle-Mariotte-Gesetz.
#
# Zunächst wird der Rezipient evakuiert und durch Schließen von V2 vom restlichen System getrennt. Anschließend wird durch wiederholtes Öffnen von V3 ein Druckausgleich zwischen Rezipient und Referenzvolumen hergestellt. Der dabei von T3 angezeigte Druck $p_{\mathrm{RZ}}^{\mathrm{(T3)}}$ wird nach Erreichen des Gleichgewichtszustands aufgenommen. Danach wird V3 wieder geschlossen und über B2 erneut Atmosphärendruck im Referenzvolumen eingestellt. Dieser Vorgang wird bis zu einem Druck von etwa $80\,\mathrm{mbar}$ wiederholt.
#
# Die Druckänderung ergibt sich aus
#
# $$
# \Delta p_i
# =
# \frac{V_{\mathrm{RV}}}{V_{\mathrm{RV}}+V_{\mathrm{RZ}}}
# \left(p_0-p_{\mathrm{RZ},i}\right).
# $$
#
# Mit
#
# $$
# p_{\mathrm{RZ},i+1}
# =
# p_{\mathrm{RZ},i}+\Delta p_i
# $$
#
# werden die tatsächlichen Druckwerte rekursiv bestimmt. Aus den Datenpunkten
#
# $$
# \left(
# p_{\mathrm{RZ},i},
# p_{\mathrm{RZ},i}^{\mathrm{(T3)}}
# \right)
# $$
#
# wird anschließend die Kalibrationskurve
#
# $$
# K\left(p_{\mathrm{RZ}}, p_{\mathrm{RZ}}^{\mathrm{(T3)}}\right)
# $$
#
# des Vakuummeters T3 erstellt.
#
# ---

# %% [markdown]
# Zunächst wird ein linearer Fit, dann ein Fit zu einem Polynom höherer Ordnung gemacht. Die Unsicherheiten der aufgenommenen Messwerte $p_{\mathrm{RZ},i}^{\mathrm{(T3)}}$ wurden dabei als 0.5 % angenommen. Dieser Fehler wurde entsprechend der Auflösung der Anzeige gewählt.

# %%
import numpy as np
import matplotlib.pyplot as plt
from uncertainties import ufloat
import uncertainties.unumpy as unp
from kafe2 import Fit, MultiFit, Plot, HistFit, HistContainer, XYContainer


uV_RV = ufloat(0.034, 0)#in l
uV_RZ = ufloat(10.8, 0.3) #in l
up_0 = ufloat(1000,1) #in mbar

p_RZ_T3 = np.array([0.285, 4.05, 8.48, 13.1, 18.3, 23.8, 29.5, 36.1, 43.7, 51.0, 59.8, 70.0, 80.1,96.6, 115.0, 134, 153, 176, 217, 251])
up_RZ_T3 = unp.uarray(p_RZ_T3, p_RZ_T3*0.005)


ufaktor = uV_RV / (uV_RV + uV_RZ)

# Array für berechnete reale Drücke
up_RZ = unp.uarray(np.zeros(len(up_RZ_T3)), 0)

# Startwert
up_RZ[0] = up_RZ_T3[0]

# Rekursive Berechnung
for i in range(len(up_RZ) - 1):
    delta_p = ufaktor * (up_0 - up_RZ[i])
    up_RZ[i + 1] = up_RZ[i] + delta_p

# modelle
def polynom(x, a, b, c, d):
    return a*x**b + c*x+d

def linear(x, a, b):
    return a*x + b

# cutte bei 80 mbar

up_RZ_T3_cut = up_RZ_T3[0:13]
up_RZ_cut = up_RZ[0:13]

xydata = XYContainer( unp.nominal_values(up_RZ_cut), unp.nominal_values(up_RZ_T3_cut))
xydata.add_error(axis='x', err_val=unp.std_devs(up_RZ_cut))
xydata.add_error(axis= 'y', err_val= unp.std_devs(up_RZ_T3_cut))
xydata.label= "Kalibrationskurve von T3"

fit = Fit(data=xydata, model_function=linear)

# do the fit
fit.do_fit()
plot = Plot(fit)

# data
plot.x_label = r"$p_{\mathrm{RZ}}$ [mbar]"
plot.y_label = r"$p_{\mathrm{RZ}}^{(T3)}$ [mbar]"
plot.plot()
plt.show()

# create the Fit object by specifying a density function
fit = Fit(data=xydata, model_function=polynom)

# do the fit
fit.do_fit()
plot = Plot(fit)

# data
plot.x_label = r"$p_{\mathrm{RZ}}$ [mbar]"
plot.y_label = r"$p_{\mathrm{RZ}}^{(T3)}$  [mbar]"
plot.plot()
plt.show()
# Out:
# C:\Users\Stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\uncertainties\core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# C:\Users\Stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafe2\fit\_base\fit.py:1091: UserWarning: Intial values and step sizes for one or more fit parameters are not well-defined: ['a', 'b']. For better convergence set initial values != 0, set initial step sizes via parameter_errors, or limit, fix, or constrain the parameters.
#   warnings.warn(
# ...

# %% [markdown]
# Die Tupel $\left(p_{\mathrm{RZ},i},p_{\mathrm{RZ},i}^{\mathrm{(T3)}}\right)$ wurden wie oben erklärt bestimmt und auf zwei Modelle gefittet. Das lineare Modell zeigt gerade bei höher werdenden Drücken eine geringe Übereinstimmung mit den Messdaten. Das kann man auch an dem sehr hohen $\chi^2/\alpha$ - Wert von 41.82 sehen.
# Das zweite Modell hat zusätzlich zu dem linearen Anteil noch einen Term höherer Ordnung:
#
# $$
# f(x) = a \cdot x^b + c \cdot x + d.
# $$
#
# Die Pameter für dieses Modell wurden als $a = 0.13 \pm 0.01$, $b = 2.19 \pm 0.21$, $c = 1.160 \pm 0.058$ und $d = -0.047 \pm 0.016$ bestimmt. Das Modell passt sehr gut zu den Datenpunkten, was man an dem sehr kleinen $\chi^2/\alpha$ - Wert von 0.1869 sehen kann. Dieser Wert ist viel kleiner als 1 und damit passt der Fit eher zu gut zu den Daten. Dies spricht für zu konservativ angenommene Unsicherheiten.
#
# Da die Datenpunkte deutlich von dem idealen Modell $p_{\mathrm{RZ}}^{\mathrm{(T3)}}(p_{\mathrm{RZ}}) = \alpha\,p_{\mathrm{RZ}}+\beta$ (mit $\beta$ = 0 und $\alpha$ = 1) abweichen, kann man gerade bei hohen Drücken von einer ungenügenden Kalibration des Wärmeleitungs-Vakuummeters ausgehen.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 3.2: Elektrische Durchschlagfestigkeit
#
#  - Untersuchen Sie die elektrische Durchschlagfestigkeit der Kugelelektroden (KE) als Funktion des Umgebungsdrucks für Luft.
#  - Diese Aufgabe kann nur an den Apparaturen 151 und 152 durchgeführt werden.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# In diesem Versuch wird die elektrische Durchschlagfestigkeit der Kugelelektroden (KE) in Luft als Funktion des Umgebungsdrucks untersucht. Dazu wird die Spannung $U_{\mathrm{KE}}$ bestimmt, bei der zwischen den Elektroden eine Gasentladung beziehungsweise ein Plasma auftritt.
#
# Zunächst wird der Rezipient ausschließlich mit der Drehschieberpumpe (DSP) evakuiert, während die Turbomolekularpumpe (TMP) ausgeschaltet bleibt. Die Messung beginnt bei Atmosphärendruck. Für jeden Messpunkt wird nach Erreichen des gewünschten Drucks das Ventil V1 geschlossen, damit der Druck im Rezipienten konstant bleibt. Anschließend wird die Spannung zwischen den Kugelelektroden schrittweise erhöht, bis eine Entladung beobachtet wird. Der zugehörige Druck sowie die Durchbruchsspannung werden notiert.
#
# Der Druck wird danach schrittweise weiter abgesenkt, zunächst bis etwa
#
# $$
# p \approx 0.08\,\mathrm{mbar}.
# $$
#
# Um zusätzliche Messpunkte bei kleineren Drücken zu erhalten, wird anschließend auch die TMP verwendet, bis der minimale erreichbare Druck von ungefähr
#
# $$
# p \lesssim 10^{-4}\,\mathrm{mbar}
# $$
#
# erreicht ist. Danach wird die TMP abgeschaltet und V2 geschlossen. Durch den nun langsam ansteigenden Druck können weitere Messwerte aufgenommen werden.
#
# Insgesamt wurden 19 Datenpunkte der Form
#
# $$
# \left(U_{\mathrm{KE}},\,p_{\mathrm{RZ}}\right)
# $$
#
# bestimmt werden. Spannungen werden mit einem Multimeter gemessen.
#
# ---

# %% [markdown]
# Wie im vorherigen Versuch werden Drücke p mit einer Unsicherheit von 0.5 % versehen. Da die Spannungen während der Messung stark fluktuiert haben, wird hier von einer Unsicherheit von 5 % ausgegangen.

# %%
import numpy as np
U1 = np.array([4.2, 1.1, 1.0, 0.84, 0.68, 0.57, 0.43, 0.38, 0.39, 0.36, 0.395, 0.49, 0.58, 0.51, 0.48])#in kV
p1 = np.array([1000, 430, 258, 135, 70, 40, 17, 9, 4.9, 2.5, 1.3, 0.56, 0.28, 0.16, 0.12])#in mbar

U2 = np.array([1.7, 0.97, 0.58, 0.48])#in kV
p2 = np.array([0.001, 0.002, 0.009, 0.07])# in mbar

U = np.concatenate((U1, U2))
p = np.concatenate((p1, p2))

plt.figure()
plt.errorbar(p, U, xerr=0.005*p, yerr=0.05*U, fmt='o')
plt.xlabel('Druck (mbar)')
plt.ylabel('Spannung (kV)')     

plt.xscale("log")
plt.title('Durchschlagsfeldstärke in Luft')
plt.grid()
plt.show()

# %% [markdown]
# Die aufgenommenen Spannungen entsprechen jeweils dem Maximalwert unmittelbar vor der Entladung. Sobald zwischen den Kugeln ein Ladungsausgleich durch Funkenüberschlag oder bei niedrigen Drücken durch eine Glimmentladung stattfindet, sinkt die Spannung leicht ab, da nun ein Strom fließt.
#
# Zur besseren Darstellung des Bereichs minimaler Überschlagsspannung wurde eine logarithmische x-Achse gewählt. Es ist erkennbar, dass die Überschlagsspannung bei sehr kleinen Drücken wieder ansteigt. Anfangs lag sie sogar oberhalb der maximal verfügbaren Spannung von $9\,\mathrm{kV}$ und konnte daher nicht gemessen werden.
#
# Liegt die mittlere freie Weglänge der Gasteilchen in der Größenordnung des Elektrodenabstands, so wird die Überschlagsspannung besonders klein. Wird der Druck weiter erhöht, verkleinert sich die mittlere freie Weglänge erneut, wodurch die Durchschlagfestigkeit wieder zunimmt.
#
# Dieses Verhalten kann man gut im Graph oben ablesen. Im Bereich 0.01 - 10 mbar bildet sich ein Plateau als Minimum der Überschlagsspannung.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 3.3: Aufdampfen von Indium
#
# Dampfen Sie mit Hilfe einer Schablone bei zwei verschiedenen Drucken Indium auf eine Plexiglasplatte auf.
#
# </div>

# %% [markdown]
# Im letzten Versuch wurde eine Indium-Schicht durch eine Kreisblende auf eine Plexiglasscheibe aufgedampft. Dazu wurde ein Verdampferschiffchen mithilfe eines Heizstroms erhitzt, sodass das darauf platzierte Indium verdampfte und sich auf der Scheibe ablagerte.
#
# Die Beschichtung sollte bei zwei verschiedenen Drücken durchgeführt werden:
#
# $$
# p_1 \lesssim10^{-4}\,\mathrm{mbar}, \qquad
# p_2 \approx 10^{-3}\,\mathrm{mbar}.
# $$
#
# Der aufgedampfte Indiumkreis (s. Bild unterer Kreis) war nicht viel größer als die Kreisblende und besaß scharfe Ränder. Dies lässt sich dadurch erklären, dass bei sehr niedrigem Druck nur wenige Gasatome vorhanden sind, welche den Indiumdampf streuen könnten. Der Dampf erreicht die Plexiglasscheibe daher nahezu geradlinig.
#
# Im Druckbereich von $p_2$ war der Indiumkreis (s. Bild oberer Kreis) größer und an den Rändern unschärfer. Das liegt daran, dass mehr Gasatome vorhanden sind, welche den Indiumdampf streuen und ablenken.
#
# Außerdem wurde beobachtet, dass im Bereich $p_2$ ein größerer Heizstrom benötigt wurde ($\approx$ 40 A). Mit zunehmendem Druck verbessert sich die Wärmeleitung des Gases, wodurch mehr Wärme abgeführt wird. Um dennoch die notwendige Verdampfungstemperatur zu erreichen, ist daher ein größerer Heizstrom erforderlich.

# %%
from os import getcwd
PWD=getcwd()

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = plt.figure("demo", figsize=(10.0, 10.0))
img = mpimg.imread("3_3.jpeg".format(PWD=PWD))
imgplot = plt.imshow(img)
imgplot.axes.get_xaxis().set_visible(False)
imgplot.axes.get_yaxis().set_visible(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 8
#       5 import matplotlib.image as mpimg
#       7 img = plt.figure("demo", figsize=(10.0, 10.0))
# ----> 8 img = mpimg.imread("3_3.jpeg".format(PWD=PWD))
#       9 imgplot = plt.imshow(img)
#      10 imgplot.axes.get_xaxis().set_visible(False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\image.py:1520, in imread(fname, format)
#    1513 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1514     # Pillow doesn't handle URLs directly.
#    1515     raise ValueError(
#    1516         "Please open the URL for reading and pass the "
#    1517         "result to Pillow, e.g. with "
#    1518         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1519         )
# ...

# %% [markdown]
# # Beurteilung

# %%
from os import getcwd
PWD=getcwd()

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = plt.figure("demo", figsize=(10.0, 10.0))
img = mpimg.imread("Beurteilung.png".format(PWD=PWD))
imgplot = plt.imshow(img)
imgplot.axes.get_xaxis().set_visible(False)
imgplot.axes.get_yaxis().set_visible(False)
plt.show()
