# %% [markdown]
# # Fakultät für Physik
#
# ## Physikalisches Praktikum P2 für Studierende der Physik
#
# Versuch **H14** (Stand: **April 2026**)
#
# [Raum F1-08](https://labs.physik.kit.edu/img/Klassische-Praktika/Lageplan_P2.png)
#
#
#
# # [Ideales und reales Gas](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Ideales_und_reales_Gas/README.md)

# %% [markdown]
# Name: __________________ Vorname: __________________ E-Mail: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Name: __________________ Vorname: __________________ E-Mail: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Gruppennummer: _____
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
#
# Betreuer: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Versuch durchgeführt am: __________________

# %% [markdown]
# ---
#
# **Beanstandungen zu Protokoll Version _____:**
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# \end{split}
# %\text{\vspace{10cm}}
# \end{equation*}
#
# <br>
# Testiert am: __________________ Testat: __________________

# %% [markdown]
# # Durchführung

# %% [markdown]
# ℹ️ **Detaillierte Kommentare zur Durchführung der Aufgaben finden Sie in der Datei [Ideales_und_reales_Gas_Hinweise.ipynb](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Ideales_und_reales_Gas/Ideales_und_reales_Gas_Hinweise.ipynb)**

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 1: Messung des absoluten Nullpunkts der Temperatur
#
#  * Bestimmen Sie den [**Volumenausdehnungskoeffizienten**](https://de.wikipedia.org/wiki/Ausdehnungskoeffizient) $\gamma$ von Luft mit Hilfe eines Gasthermometers.
#  * Berechnen Sie daraus die **Temperatur des absoluten Nullpunkts** $\vartheta_{0}$ in $^{\circ}\mathrm{C}$.
#  * Überprüfen Sie den Effekt, den die **Ausdehnung des Glaskolbens K** als Funktion von $\vartheta$ hat und korrigieren Sie Ihre Messung ggf. entsprechend.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %%
T = [5.7, 99.9]
delta_h = [3.5, 23.1]

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 2: Messung des Adiabatenexponenten $\kappa$
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.1: Messung nach der Methode von [Clément-Desormes](https://de.wikipedia.org/wiki/Experiment_von_Cl%C3%A9ment-Desormes)
#
#  * Bestimmen Sie $\kappa$ nach der **Methode von Clément-Desormes**.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %%
import numpy as np
# 3s
delta_h1_3 = np.array([110, 114, 210, 135, 105, 145, 125, 133, 191, 88])#mm
delta_h2_3 = np.array([21, 30, 53, 33, 24, 34, 28, 30, 51, 21])

# 1s
delta_h1_1 = np.array([131, 174, 166, 132, 104])#mm
delta_h2_1 = np.array([77, 91, 93, 74, 50])         

# 5s
delta_h1_5 = np.array([127, 160, 121, 104, 149])#mm
delta_h2_5 = np.array([25, 32, 24, 17, 29])


arr_kappa_3 = delta_h1_3/(delta_h1_3 - delta_h2_3)
arr_kappa_1 = delta_h1_1/(delta_h1_1 - delta_h2_1)
arr_kappa_5 = delta_h1_5/(delta_h1_5 - delta_h2_5)

kappa_3, kappa_1, kappa_5 = np.mean(arr_kappa_3), np.mean(arr_kappa_1), np.mean(arr_kappa_5)
kappa_3_std, kappa_1_std, kappa_5_std = np.std(arr_kappa_3), np.std(arr_kappa_1), np.std(arr_kappa_5)


weights_3 = 1 / kappa_3_std**2
weights_1 = 1 / kappa_1_std**2
weights_5 = 1 / kappa_5_std**2

mean_3 = np.sum(weights_3 * kappa_3) / np.sum(weights_3)
mean_1 = np.sum(weights_1 * kappa_1) / np.sum(weights_1)
mean_5 = np.sum(weights_5 * kappa_5) / np.sum(weights_5)

print(f"mean (1s): {mean_1:.5f} +/- {np.sqrt(1/np.sum(weights_1)):.5f}")
print(f"mean (3s): {mean_3:.5f} +/- {np.sqrt(1/np.sum(weights_3)):.5f}")
print(f"mean (5s): {mean_5:.5f} +/- {np.sqrt(1/np.sum(weights_5)):.5f}")
# Out:
# mean (1s): 2.19961 +/- 0.17212
# mean (3s): 1.31145 +/- 0.03549
# mean (5s): 1.23592 +/- 0.02044

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.2: Messung nach der Methode von [Rüchardt](https://de.wikipedia.org/wiki/R%C3%BCchardt-Experiment)
#
#  * Bestimmen Sie $\kappa$ nach der **Methode von Rüchardt**.
#
# **Für diese Aufgabe stehen Ihnen zwei Messaufbauten zur Verfügung. Sie können zwischen einem Aufbau nach der originalen Methode nach Rüchard und einem Aufbau mit elektronischer Datenaufzeichnung und Kolbenprober wählen. Das Messprinzip ist für beide Aufgaben gleich. Nach der originalen Methode von Rüchard bestimmen Sie $\kappa$ nur für Luft. Mit dem Aufbau mit elektronischer Datenaufzeichnung und Kolbenprober bestimmen Sie $\kappa$ für Luft und für das Edelgas Argon (Ar).**
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %%
from uncertainties import ufloat
from uncertainties import unumpy as unp

um = ufloat(0.1098, 0.005)
up = ufloat(100000, 200)

ud = ufloat(0.0311, 0.001)
uA= np.pi * (ud/2)**2

# Luft
uV = unp.uarray([30, 40, 50, 60, 70, 80], 5)*0.001*0.001#m^3
uf_1 = unp.uarray([26.89, 21.76, 19.54, 17.98, 16.65, 15.57], 0.2)#Hz

# Argon
uf_2 = unp.uarray([25.97, 22.23, 20.11, 18.04, 16.67, 15.72], 0.2)#Hz

# berechnung k luft


uk_values = []
for V_i, f_i in zip(uV, uf_1):
    uk_i = (2*np.pi * f_i)**2 * V_i* um / (up*uA**2)
    uk_values.append(uk_i)

print("k Luft:" +str(uk_values))
# Out:
# k Luft:[1.6294596746668604+/-0.3518241976443205, 1.4227170342607864+/-0.2645755932398215, 1.4340354291087367+/-0.24437213574476355, 1.4570396933035377+/-0.23520902175999062, 1.4576970459895287+/-0.22722906834926665, 1.456826960723635+/-0.2218318586216254]

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 3: Dampfdruckkurve von n-Hexan
#
#  * Bestimmen Sie den Verlauf der **Dampfdruckkurve** von n-Hexan zwischen Zimmertemperatur und $0^{\circ}\mathrm{C}$.
#  * Schätzen Sie aus Ihrer Messung die **molare Verdampfungswärme $Q_{\mathrm{M}}$** ab.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %%
T0 = 24.9
h_links = 44.35
h_rechts = 34.9

# nur messung von rechts da annahmen das Hg inkompressibel
T_sinkend = [23.2, 21.6, 19.5, 16.9, 15.2, 13.3, 10.3, 8.2, 6.3, 4.4, 0.9]
h_sinkend_rechts = [35.2, 35.5, 35.9, 36.1, 36.7, 37.15, 37.65, 38.05, 38.25, 38.5, 38.85]

T_steigend = [6.1, 8.0, 10.0, 11.0, 12.0, 13.0, 14.0, 15.1, 16.0, 17.3, 18.1, 19.1, 20.2]
h_steigend_rechts = [38.2, 37.9, 37.6, 37.5, 37.3, 37.1, 36.95, 36.8, 36.6, 36.4, 36.25, 36.1, 35.9]

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# # Beurteilung

# %% [markdown]
#  * Beurteilen Sie diesen Versuch nach Abschluss der Auswertung.
#  * **Folgen Sie zur Beurteilung dieses Versuchs diesem [Link](https://www.empirio.de/s/bVWYhGYWmG)**.
#  * Beachten Sie, dass jede:r Studierende nur einmal pro Versuch eine Beurteilung abgeben kann.

# %% [markdown]
# **Lösung:**
#
# Fügen Sie Ihrem Protokoll einen Screenshot der letzten Informationsseite der oben verlinkten Beurteilung zu.
