# %% [markdown]
# # Hinweise zum Versuch **Operationsverstärker (OPV)**
#
# ---
#
#  * Eine kurze Einführung in die **Grundbegriffe und den Einsatz des OPV** finden Sie in der Datei [Hinweise-OPV](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Operationsverstaerker/doc/Hinweise-OPV.md).
#  * Einen Einblick in die **Innenbeschaltung** des in diesem Versuch verwendeten OPV finden Sie in der Datei [Hinweise-Innenbeschaltung](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Operationsverstaerker/doc/Hinweise-Innenbeschaltung.md).
#  * Praktische **Hinweise zur allgemeinen Versuchsdurchführung** finden Sie in der Datei [Hinweise-Versuchsdurchfuehrung](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Operationsverstaerker/doc/Hinweise-Versuchsdurchfuehrung.md).
#
# ---

# %% [markdown]
# ## Aufgabe 1: Spannungsteiler und Impedanzwandler
#
# ---
#
# Hinweise zum **Spanungsteiler** finden Sie in der Datei [Hinweise-Spannungsteiler](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Spannungsteiler.md).
#
# Hinweise zu den **Grundschaltugnen des OPV** finden Sie in der Datei [Hinweise-OPV](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-OPV.md).
#
# ---

# %% [markdown]
# ### Aufgabe 1.1: Ohmscher Spannungsteiler

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Verwenden Sie zum Aufbau die Schaltung aus **Abbildung 1** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Spannungsteiler.md).
#  * Verwenden Sie für den Aufbau einen Widerstand von $\mathrm{R_1} = 11,5 \mathrm{k\Omega}$ und $\mathrm{R_2} = 2,26 \mathrm{k\Omega}$
#  * Beachten Sie:
#    * Die äußere Spannungsversorgung des [Steckbretts](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Versuchsdurchfuehrung.md) ist auf $\pm12\,\mathrm{V}$ vorgegeben.
#  * Legen Sie zur Überprüfung der Schaltung am Funktionsgenerator eine **Sinusspannung mittlerer Frequenz** (z.B. $\nu=1\,\mathrm{kHz}$) und einer Amplitude von $9 \mathrm{V}$ für $U_{in}$ an und stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#  * Überzeugen Sie sich davon, dass der Spannungsteiler die erwartete Spannungsreduktion aufweist.
#    * Nehmen Sie hierzu das Oszillogramm auf und vegleichen Sie die Amplitudes des Eingangs- und Ausgangssignals.
# * Beobachten Sie nun, wie sich das Ausgangssignal verhält, wenn Sie ein **Hochfrequentes Rechtecksignal** am Eingang verwenden.
#    * Variieren Sie dabei die Frequenz des Rechtecksignals, bis Sie eine Verzerrung beobachten können.
#    * Nehmen Sie von dem verzerrten Ausangssignal ein Oszillogramm auf.
#
# **Hinweise zur Auswertung:**
#
#  * Fügen Sie Ihrer Auswertung das Schaltbild aus **Abbildung 1** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Spannungsteiler.md) bei.
#    * Eine Erklärung, wie Sie externe Bilder in Ihr Protokoll einfügen können finden Sie [hier](https://gitlab.kit.edu/kit/etp-lehre/p1-praktikum/students/-/blob/main/tools/add_figures.ipynb).
#  * Erklären Sie zur Vorbereitung auf den Versuch die **erwartete Spannungsreduktion**, für die von Ihnen vorgesehene Schaltung.
#  * Dokumentieren Sie während der Messung Ihr Vorgehen.
#  * Fügen Sie Ihrer Auswertung eine **Photographie Ihres Aufbaus, sowie eine geeignete gemeinsame Darstellung von $U_{in}$ und $U_{out}$ am Oszilloskop** bei.
#  * Widerholen Sie dieses Vorgehen für das **Rechtecksignal**.
#     * Beschreiben Sie, wie die Verzerrung des Rechtecksignals zustande kommt.

# %% [markdown]
# ### Aufgabe 1.2: Frequenzkompensierter Spannungsteiler

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Verwenden Sie zum Aufbau die Schaltung aus **Abbildung 6** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Spannungsteiler.md).
#  * Verwenden Sie für den Aufbau einen Widerstand von $\mathrm{C_1} = 82 \mathrm{pF}$ parallel zu einem Trimmer Kondensator mit einer Kapazität von $\mathrm{C_T} = (6 - 30) \mathrm{pF}$ und $\mathrm{R_2} = 470 \mathrm{pF}$
#  * Legen Sie zur Überprüfung der Schaltung am Funktionsgenerator eine **Sinusspannung mittlerer Frequenz** (z.B. $\nu=1\,\mathrm{kHz}$) für $U_{e}$ an und stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#  * Überzeugen Sie sich davon, dass der Spannungsteiler das erwartete Verhalten aufweist.
#  * Legen Sie nun ein **Rechtecksignal** an und justieren Sie den Trimmerkondensator, bis die Verzerrung minimal wird.
#
# **Hinweise zur Auswertung:**
#
#  * Fügen Sie Ihrer Auswertung das Schaltbild aus **Abbildung 6** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Spannungsteiler.md) bei.
#    * Eine Erklärung, wie Sie externe Bilder in Ihr Protokoll einfügen können finden Sie [hier](https://gitlab.kit.edu/kit/etp-lehre/p1-praktikum/students/-/blob/main/tools/add_figures.ipynb).
#  * Dokumentieren Sie während der Messung Ihr Vorgehen.
#  * Fügen Sie Ihrer Auswertung **eine geeignete gemeinsame Darstellungen von $U_{in}$ und $U_{out}$ am Oszilloskop** bei.

# %% [markdown]
# ### Aufgabe 1.3: Offset-Addition

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Verwenden Sie zum Aufbau die Schaltung aus **Abbildung 9** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Spannungsteiler.md).
#  * Verwenden Sie dabei einen Widerstand von $\mathrm{R_3} = 2,87 \mathrm{k\Omega}$ und $\mathrm{R_4} = 16,2 \mathrm{k\Omega}$
#  * Schließen Sie einen $100 \mathrm{nF}$ Kondensator an den Eingang des Spannungsfolgers an, um Spannugsschwankungen abzufangen.
#  * Legen Sie zur Überprüfung der Schaltung am Funktionsgenerator eine **Sinusspannung mittlerer Frequenz** (z.B. $\nu=1\,\mathrm{kHz}$) für $U_{e}$ an und stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#  * Überzeugen Sie sich davon, dass der Spannungsteiler das erwartete Verhalten aufweist.
#
# **Hinweise zur Auswertung:**
#
#  * Fügen Sie Ihrer Auswertung das Schaltbild aus **Abbildung 9** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Spannungsteiler.md) bei.
#    * Eine Erklärung, wie Sie externe Bilder in Ihr Protokoll einfügen können finden Sie [hier](https://gitlab.kit.edu/kit/etp-lehre/p1-praktikum/students/-/blob/main/tools/add_figures.ipynb).
#  * Dokumentieren Sie während der Messung Ihr Vorgehen.
#  * Fügen Sie Ihrer Auswertung **eine geeignete gemeinsame Darstellungen von $U_{in}$ und $U_{out}$ am Oszilloskop** bei.
#  * Beschreiben Sie, wie das Ausgangssignal zustande kommt
#     * Beschreiben Sie die Rolle des **Operationsverstärkers als Spannungsfolger** in dieser Schaltung.

# %% [markdown]
# ### Aufgabe 1.4: Impedanzwandler

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Fügen Sie ihrer Schaltung am Ausgang einen **Impedanzwandler (Spannungsfolger)** hinzu.
#  * Überzeugen Sie sich davon, dass die Ausgangsspannung unverändert bleibt.
#  * Schließen Sie nun einen mit Masse verbundenen **Lastwiderstand** an den Ausgang des Spannugnsteilers (vor dem Impedanzwandler) und beobachten Sie den Spannungseinbruch.
#    * Nehmen Sie dazu ein Oszillogramm mit dem Oszilloksop auf. Stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#  * Platzieren Sie nun den Lastwiderstand am Ausgang des Spannungsfolgers.
#    * Nehmen Sie dazu ein Oszillogramm mit dem Oszilloksop auf. Stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#
# **Hinweise zur Auswertung:**
#
#  * Dokumentieren Sie während der Messung Ihr Vorgehen.
#  * Fügen Sie Ihrer Auswertung **eine geeignete gemeinsame Darstellungen von $U_{in}$ und $U_{out}$ am Oszilloskop** bei.
#  * Vergleichen Sie das Ausgangssignal für beide Positionen des Lastwiderstands.
#  * Erklären Sie die Funktionsweise des OPV anhand der **Goldenen Regeln**

# %% [markdown]
# ## Aufgabe 2: Nicht-invertierender Verstärker
#
# ---
#
# Hinweise zu den **Grundschaltugnen des OPV** finden Sie in der Datei [Hinweise-OPV](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-OPV.md).
#
# ---

# %% [markdown]
# ### Aufgabe 2.1: Nicht-Invertierender Spannungsverstärker

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Verwenden Sie zum Aufbau die Schaltung aus **Abbildung 6** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-OPV.md).
#  * Verwenden Sie für den Aufbau der Schaltung einen Widerstand von $2,87 \mathrm{k\Omega}$ und einen Widerstand von $16,2 \mathrm{k\Omega}$
#    * Probieren Sie beide Widerstandskonfigurationen aus
#    * Überzeugen Sie sich davon, dass der Verstärker die erwartete Spannungsverstärkung aufweist.
#    * Gehen Sie ansonsten analog zu **Aufgabe 1.1** vor.
#  * Legen Sie zur Überprüfung der Schaltung am Funktionsgenerator eine **Sinusspannung mittlerer Frequenz** (z.B. $\nu=1\,\mathrm{kHz}$) und einer Amplitude von $3 \mathrm{V}$ für $U_{in}$ an und stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#  * Beobachten Sie nun das Sättigungsverhalten des OPV
#    * Bauen Sie hierzu die beiden Widerstände so ein, dass Sie einen Verstärkungsfaktor von $\frac{U_{out}}{U_{in}} = 3$ erhalten
#    * Erhöhen Sie dazu die **Amplitude des Eingangssignals**, bis die Ausgangsspannung des OPV gesättigt ist.
#    * Nehmen Sie dazu ein Oszillogramm mit dem Oszilloksop auf. Stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#  * Beobachten Sie nun das Verhalten des Ausgangssignals beim Anlegen eines **DC-Offsets** am Eingang
#    * Nehmen Sie dazu ein Oszillogramm mit dem Oszilloksop auf. Stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#
# **Hinweise zur Auswertung:**
#
#  * Fügen Sie Ihrer Auswertung das Schaltbild aus **Abbildung 6** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-OPV.md) bei.
#    * Eine Erklärung, wie Sie externe Bilder in Ihr Protokoll einfügen können finden Sie [hier](https://gitlab.kit.edu/kit/etp-lehre/p1-praktikum/students/-/blob/main/tools/add_figures.ipynb).
#  * Erklären Sie zur Vorbereitung auf den Versuch die **erwartete Spannungsverstärkung**, für die von Ihnen vorgesehene Schaltung.
#  * Dokumentieren Sie während der Messung Ihr Vorgehen.
#  * Fügen Sie Ihrer Auswertung eine **Photographie Ihres Aufbaus, sowie eine geeignete gemeinsame Darstellungen von $U_{in}$ und $U_{out}$** für beide Widerstandskonfigurationen **am Oszilloskop** bei.
#    * Fügen Sie auch eine Darstellung von **$U_{in}$ und $U_{out}$ am Oszilloskop** für das Sättigungeverhalten sowie den DC-Offset ein

# %% [markdown]
# ### Aufgabe 2.2: Verstärkungsgesetz

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Ersetzen Sie in ihrer Schaltugn den Widerstand $R_2$ durch ein Potentiometer
#  * Nehmen Sie fünf Oszillogramme mit verschiedenen **Verstärkungsfaktoren** und zugehörigen **Potentiometer-Einstellungen** auf.
#    * Verwenden Sie für das Eingangssignal eine Amplitude von $3 \mathrm{V}$. Wählen Sie fünf geeignete Ausgangsamplituden im Bereich von $3 \mathrm{V}$ bis $9 \mathrm{V}$
#    * Variieren Sie für jede der fünf Messungen das Potentiometer, bis die gewünschte Ausgangsamplitude erreicht wird
#    * Entfernen Sie nun den Potentiometer aus der Schaltung und Messen Sie den Widerstand
#
# **Hinweise zur Auswertung:**
#
#  * Stellen Sie die Messpunkte ($\frac{U_{out}}{U_{in}}$, $\frac{R_1}{R_2}$) geeignet dar und passen die ein geeignetes Modell daran an.
#    * Überprüfen Sie die Anwendbarkeit des Modells auf die Messpunkte auf Grundlage des χ2-Werts der Anpassung.
#    * Wählen Sie für den Widerstand $R_2$ eine Ungenauigkeit von $5\%$.
#    * Schätzen Sie die Unsicherheit der Messung des Widerstands am Potentiometer durch das Multimeter-Messgerät geeignet ab.

# %% [markdown]
# ### Aufgabe 2.3: Clamping-Dioden

# %% [markdown]
# **Diese Aufgabe ist nicht verpflichtend.**
#
# **Hinweise zum Ablauf:**
#
#  * Verwenden Sie zum Aufbau die Schaltung aus **Abbildung 1** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Komplexe-Schaltungen.md).
#  * Verwenden Sie für $R_1$ und $R_2$ die beiden Widerstände, die Sie bisher für diese Aufgabe zur Verfügung hatten.
#  * Überzeugen Sie sich davon, dass sich die Clamping-Dioden Ihrer Erwartung gemäß verhalten.
#
# **Hinweise zur Auswertung:**
#
#  * Fügen Sie Ihrer Auswertung das Schaltbild aus **Abbildung 1** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Komplexe-Schaltungen.md) bei.
#    * Eine Erklärung, wie Sie externe Bilder in Ihr Protokoll einfügen können finden Sie [hier](https://gitlab.kit.edu/kit/etp-lehre/p1-praktikum/students/-/blob/main/tools/add_figures.ipynb).
#  * Erklären Sie zur Vorbereitung auf den Versuch die **erwartete Funktionsweise** der Clamping Dioden.
#  * Fügen Sie Ihrer Auswertung eine **Photographie Ihres Aufbaus, sowie eine geeignete gemeinsame Darstellungen von $U_{in}$ und $U_{out}$ am Oszilloskop** bei.
#  * Gehen Sie in der Darstellung auf den beobachteten Effekt ein.

# %% [markdown]
# ## Aufgabe 3: Invertierender Verstärker
#
# ---
# Hinweise zu den **Grundschaltugnen des OPV** finden Sie in der Datei [Hinweise-OPV](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-OPV.md).
#
# Wichtige Hinweise zur Vorbereitung auf diese Aufgabe finden Sie in der Datei [Hinweise-Komplexere-Schaltungen](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Operationsverstaerker/doc/Hinweise-Komplexere-Schaltungen.md).
#
# ---

# %% [markdown]
# Aufgabe 3.1: Invertierender Verstärker

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Verwenden Sie zum Aufbau die Schaltung aus **Abbildung 7** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-OPV.md).
#  * Verwenden Sie für den Aufbau der Schaltung einen Widerstand von $2,87 \mathrm{k\Omega}$ und winen Widerstand von $16,2 \mathrm{k\Omega}$
#    * Probieren Sie beide Widerstandskonfigurationen aus
#    * Überzeugen Sie sich davon, dass der Verstärker die erwartete Spannungsverstärkung aufweist.
#    * Gehen Sie ansonsten analog zu **Aufgabe 2.1** vor.
#  * Legen Sie zur Überprüfung der Schaltung am Funktionsgenerator eine **Sinusspannung mittlerer Frequenz** (z.B. $\nu=1\,\mathrm{kHz}$) und einer Amplitude von $3 \mathrm{V}$ für $U_{in}$ an und stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#
# **Hinweise zur Auswertung:**
#
#  * Fügen Sie Ihrer Auswertung das Schaltbild aus **Abbildung 7** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-OPV.md).
#    * Eine Erklärung, wie Sie externe Bilder in Ihr Protokoll einfügen können finden Sie [hier](https://gitlab.kit.edu/kit/etp-lehre/p1-praktikum/students/-/blob/main/tools/add_figures.ipynb).
#  * Erklären Sie zur Vorbereitung auf den Versuch die **erwartete Funktionsweise** dieser Schaltung anhand der **Goldenen Regeln**.
#  * Fügen Sie Ihrer Auswertung eine **Photographie Ihres Aufbaus, sowie geeignete Darstellungen von $U_{in}$ und $U_{out}$** für beide Widerstandskonfigurationen **am Oszilloskop** bei.

# %% [markdown]
# ### Aufgabe 3.2: Summierverstärker

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Verwenden Sie zum Aufbau die Schaltung aus **Abbildung 3** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Komplexere-Schaltungen.md).
#    * Verwenden Sie für den Aufbau der Schaltung einen Widerstand von $R_f = 1,15 \mathrm{k\Omega}$, einen Widerstand von $R_1 = 6,81 \mathrm{k\Omega}$ und einen Widerstand von $R_2 = 9,09 \mathrm{k\Omega}$
#    * Schließen Sie das Ausgangssignal des Funktionsgenerators ($V_1$) an de Widerstand $R_1$ an.
#    * Schließen Sie die $12 \mathrm{V}$ Versorgungsspannung ($V_2$) an den Widerstand $R_2$ an.
#  * Legen Sie zur Überprüfung der Schaltung am Funktionsgenerator eine **Sinusspannung mittlerer Frequenz** (z.B. $\nu=1\,\mathrm{kHz}$) und einer Amplitude von $9 \mathrm{V}$ für $U_{in}$ an und stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#  * Überzeugen Sie sich davon, dass sich die Schaltung Ihrer Erwartung gemäß verhält.
#
# **Hinweise zur Auswertung:**
#
#  * Fügen Sie Ihrer Auswertung das Schaltbild aus **Abbildung 3** [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/doc/Hinweise-Komplexere-Schaltungen.md) bei.
#    * Eine Erklärung, wie Sie externe Bilder in Ihr Protokoll einfügen können finden Sie [hier](https://gitlab.kit.edu/kit/etp-lehre/p1-praktikum/students/-/blob/main/tools/add_figures.ipynb).
#  * Erklären Sie die **erwartete Funktionsweise** dieser Schaltung.
#  * Fügen Sie Ihrer Auswertung eine **Photographie Ihres Aufbaus, sowie geeignete Darstellungen von $U_{in}$ und $U_{out}$ am Oszilloskop** bei.

# %% [markdown]
# ### Aufgabe 3.3: Invertierer

# %% [markdown]
# **Hinweise zum Ablauf:**
#
#  * Fügen Sie an dne Ausgang ihrer Schaltung einen invertierenden Verstärker mit Verstärkung $\frac{U_{out}}{U_{in}} = -1$ an
#    * Verwenden Sie dazu zwei gleich Widerstände. Die Wahl des Widerstands ist dabei Ihnen übelassen.
#  * Überzeugen Sie sich davon, dass sich die Schaltung Ihrer Erwartung gemäß verhält.
#  * Legen Sie zur Überprüfung der Schaltung am Funktionsgenerator eine **Sinusspannung mittlerer Frequenz** (z.B. $\nu=1\,\mathrm{kHz}$) und einer Amplitude von $9 \mathrm{V}$ für $U_{in}$ an und stellen Sie **sowohl $U_{in}$ als auch $U_{out}$ auf dem Oszilloskop** geeignet dar.
#
# **Hinweise zur Auswertung:**
#
#  * Erklären Sie zur Vorbereitung auf den Versuch die **erwartete Funktionsweise** dieser Schaltung.
#  * Fügen Sie Ihrer Auswertung eine **Photographie Ihres Aufbaus, sowie geeignete Darstellungen von $U_{a}$ am Oszilloskop** bei.
#  * Vergleichen Sie die Funktionsweise und den Aufbau dieser Schaltung mit der Schaltung aus **Aufgabe 1.4**
