# %% [markdown]
# # Fakultät für Physik
#
# ## Physikalisches Praktikum P2 für Studierende der Physik
#
# Versuch **H17** (Stand: **April 2025**)
#
# [Raum F1-13](https://labs.physik.kit.edu/img/Klassische-Praktika/Lageplan_P2.png)
#
#
#
# # [Signalverarbeitung](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/tree/main/Signalverarbeitung/README.md)

# %% [markdown]
# Name: __Trunzer__ Vorname: __Kiran__ E-Mail: __urmat@student.kit.edu__
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Name: __Haag___ Vorname: __Finn__ E-Mail: __uvvln@student.kit.edu__
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Gruppennummer: __Di-7, Di-16__
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
#
# Betreuer: __Andres Felipe Latorre Trujillo__
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Versuch durchgeführt am: __________________

# %% [markdown]
# ---
#
# **Beanstandungen zu Protokoll Version _____:**
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# \end{split}
# %\text{\vspace{10cm}}
# \end{equation*}
#
# <br>
# Testiert am: __________________ Testat: __________________

# %% [markdown]
# # Durchführung

# %% [markdown]
# ℹ️ **Detaillierte Hinweise zur Durchführung der Versuche finden Sie in der Datei [Signalverarbeitung_Hinweise.ipynb](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/Signalverarbeitung_Hinweise.ipynb)**

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 1: Spannungsteiler und Impedanzwandler
#
# 🔔 **Achten Sie darauf, dass die Tastköpfe des Oszilloskops kalibriert sind bevor Sie die folgenden Aufgaben bearbeiten. Weitere Hinweise hierzu finden Sie im [Datenblatt](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/Datenblatt.md#%EF%B8%8F-vor-der-verwendung-des-oszilloskops-m%C3%BCssen-sie-die-tastk%C3%B6pfe-kalibrieren-%EF%B8%8F) zum Versuch.** 🔔
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.1: Ohmscher Spannungsteiler
#
#  * Bauen Sie einen **ohmschen Spannungsteiler** aus Widerständen auf, um eine Eingangsspannung von ${\pm}9\,\mathrm{V} $ auf den Bereich von ${\pm}1.5\,\mathrm{V}$ zu reduzieren.
#  * Vergewissern Sie sich von der Funktionsweise der Schaltung.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# Vorab ist anzumerken, dass  bei allen Versuchen auf die Daten Dritter zurückgegriffen werden musste, da unsere Messdaten leider verloren gegangen sind. Das bedeutet, dass mögliche Fehlerquellen nur bedingt nachvollziehbar sind und sich Interpretationsfehler bei Abweichungen einschleichen können.
#
# Bei unserer ersten Aufgabe sollte einen ohmschen Spannungsteiler gebaut werden. Hierfür wurden zwei Widerstände $R_1=11.5\mathrm{k\Omega}$ und $R_2=2.26\mathrm{k\Omega}$ in Reihe geschaltet (siehe Abb. 1). Für den Betrieb wurde ein Funktionsgeber (FG) mit einer Sinus- und Rechteckfrequenz von $\nu=1\mathrm{kHz}$ und einer Amplitude von $9\mathrm{V}$ angelegt. Zur Messung wurde ein Oszilloskop sowohl mit dem Ausgang als auch mit dem FG selbst verbunden. Der Spannungsteiler teilt nun die Spannung proportional zu den Widerständen, sodass am größeren Widerstand eine größere Spannung abfällt. Unser Erwartungswert für die Aufgabe lässt sich nun wie folgt berechnen.
#
#
# $$
# U_2=R_2 \cdot \frac{U_0}{R_1 +R_2}= 11.5\mathrm{k\Omega} \cdot \frac{9\mathrm{V}}{11.5\mathrm{k\Omega} +2.26\mathrm{k\Omega}} = 7.522\mathrm{V}
# $$
# $$
# U_0=U_1+U_2
# $$
# $$
# U_1= U_0 - U_2 = 9\mathrm{V} - 7.522\mathrm{V} = 1.478\mathrm{V}
# $$
#
# ---

# %%
from os import getcwd
PWD = getcwd()
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("A1_1.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.29,         # vertikale Position
    "Abb.1 Ohmscher Spannungsteiler",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.29, 'Abb.1 Ohmscher Spannungsteiler')

# %%
from os import getcwd
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("v1_1.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.29,         # vertikale Position
    "Abb.2 Sinussignal",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.29, 'Abb.2 Sinussignal')

# %%
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("v1_1_2.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.29,         # vertikale Position
    "Abb.3 Rechtecksignal",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.29, 'Abb.3 Rechtecksignal')

# %% [markdown]
# |Legende:|
# |---|
# |CH1 = Eingangssignal|
# |CH2 = Ausgangssignal|
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# Das Maximum der Signale liegt wie erwartet bei $1.478\mathrm{V}$. Bei dem Rechtecksignal (Abb.3) ist interessanterweise zu sehen, dass das Ausgangssignal abgerundete Ecken hat. Dies entsteht, da das Oszilloskop einen sehr hohen Eingangswiderstand und eine niedrige Eingangskapazität hat. Dieses Problem wird in Aufgabe 1.2 behoben. Die Fehlerquellen können bei diesem Versuch die Bauelemente sein, wobei jedoch davon auszugehen ist, dass die Schaltung weniger anfällig ist als bei anderen Aufgaben, da sie sehr simpel ist und nur aus einer geringen Anzahl von Widerständen besteht, welche in der Regel eine eher hohe Genauigkeit haben. Viel warscheinlicher ist das mögliche Fehler durch parasitären Kapazitäten des Aufbaus oder der Anschlüsse erzeugt werden.
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.2: Frequenzkompensierter Spannugsteiler
#
#  * Bauen Sie zusätzlich zum ohmschen einen kapazitiven Spannungsteiler mit [Trimmkondensator](https://de.wikipedia.org/wiki/Variabler_Kondensator) in die Schaltung ein und überprüfen Sie dessen Funktionsweise.
#  * Stellen Sie den Trimmkondensator so ein, dass Sie ein Rechteck-Signal möglichst verzerrungsfrei beobachten können.
#  * Vergewissern Sie sich von der Funktionsweise der Schaltung.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# Nun sollte erneut eine Spannungsteiler gebaut werden, mit dem Unterschied, dass nun ein kapazitiver Spannungsteiler parallel geschaltet wird, mit den Kondensatoren $C_1 = 82\mathrm{pF}$ und $C_2 =470\mathrm{pF}$ (siehe Abb.4). Auch parallel zu $R_1$ und $C_1$ wird ein Trimmkondensator $C_T$ geschaltet, welcher in einem Bereich von $15-85\mathrm{pF}$ verstellbar ist. Nun soll an dem FG wieder ein Rechtecksignal mit $\nu=100\mathrm{kHz}$ angelegt werden und der Trimmkondensator so eingestellt werden, dass die Verzerrung minimal ist.
#
#
# ---

# %%
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("A1_2.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.15,         # vertikale Position
    "Abb.5 Frequenzkompensierter Spannungsteiler",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.15, 'Abb.5 Frequenzkompensierter Spannungsteiler')

# %%
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("v1_2.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.29,         # vertikale Position
    "Abb.5 Rechtecksignal (v=100kHz)",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.29, 'Abb.5 Rechtecksignal (v=100kHz)')

# %% [markdown]
# **D I S K U S S I O N**
#
# Der Kapazitive Spannungsteiler macht nun das Teilerverhältnis frequentzunabhängig indem er die Zeitkonstanten der beiden Zweige angleicht.
#
# $$
# R_1 \cdot C_1 = R_2 \cdot C_2
# $$
# Dadurch bleiben die Steilen Kanten des Rechtecksignals erhalten.
#
# Die Aufgabe des Trimmkondensators war es, die Verzerrung zu minimieren. Trotzdem kann man auf dem Signalbild immer noch eine Verzerrung erkennen. Da dies nicht unsere Messwerte sind, ist schlecht nachzuvollziehen, inwiefern dies gemacht wurde. Wir hatten jedoch auch merkbare Schwierigkeiten mit dem Trimmkondensator bei unserer Versuchsdurchführung. So wechselt dieser von dem Maximalwert zum Minimalwert ohne Übergang.
#
# ---
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.3: Offset-Addition
#
#  * Verwenden Sie einen weiteren Spannungsteiler, um die benötigte Offset-Sapnnung zu erzeugen, die das Ausgangssignal von ${\pm}1.5\, \mathrm{V}$ auf den Bereich $0\to3\,\mathrm{V}$ verschiebt.
#  * Fügen Sie der Schaltung einen zusätzlichen [Glättungskondensator](https://de.wikipedia.org/wiki/Gl%C3%A4ttungskondensator) zu, um Schwankungen in der Offsett-Spannung zu reduzieren.
#  * Vergewissern Sie sich von der Funktion der Schaltung.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# Bei diesem Versuch sollten wir eine Schaltung zur Offset-Addition aufbauen, welche die eben verwendete Schaltung des frequenzkompensierten Spannungsteilers mit einem vorgeschalteten Operationsverstärker, welcher rückgekoppelt ist und an seinem nicht-invertierenden Eingang einen Spannungsteiler sowie einen Glättungskondensator mit $C_3 = 100\mathrm{nF}$   geschalten hat (siehe Abb.5).  Der vorgeschaltete Spannungsteiler wird mit $12\mathrm{V}$ angesteuert und beinhaltet die Widerstände $R_4 = 16.2\mathrm{k\Omega}$ und $R_3=2.87\mathrm{k\Omega}$. Zusätzlich zu beachten ist das der OPV mit einer Versorgungsspannung betrieben werden muss, welche bis jetzt noch nicht extra vonnöten war. Der OPV wird nun den Eingangswert, welcher dem vorgeschalteten Spannungsteiler entspringt, als Offset-Addieren und das Signal nach oben verschieben.
#
#
# Aus der Aufgabe 1.1 wissen wir:
#
# $$
# U_2=R_3 \cdot\frac{U_0}{R_4 +R_3}= 16.2k\Omega \cdot \frac{12\mathrm{V}}{16.2\mathrm{k\Omega} +2.87\mathrm{k\Omega}} \approx 10.194\mathrm{V}
# $$
# $$
# U_0=U_1+U_2
# $$
# $$
# U_1= U_0 - U_2 = 12\mathrm{V} - 10.194\mathrm{V} = 1.806\mathrm{V}
# $$
#
# Somit sollte der Offset des Ausgangsignal $\approx 1.806\mathrm{V}$ in positiver Richtung sein.
#
#
# ---

# %%
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("A1_3.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.28,         # vertikale Position
    "Abb.5 Offset-Addition",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.28, 'Abb.5 Offset-Addition')

# %%
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("v1_3.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.28,         # vertikale Position
    "Abb.6 Offset Signal",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.28, 'Abb.6 Offset Signal')

# %% [markdown]
# **D I S K U S S I O N**
#
# Der erwartetet Offset liegt bei $\approx 1.806\mathrm{V}$. Jedoch ist in realität die Versorgungspannung bei $\approx 11.5\mathrm{V}$ anstatt der Angenommenen $12\mathrm{V}$, was den Offset auf einen Wert von $1.731\mathrm{V}$ bringt.
#
# $$
# 16.2k\Omega \cdot \frac{11.5\mathrm{V}}{16.2\mathrm{k\Omega} +2.87\mathrm{k\Omega}} \approx 9.769\mathrm{V}
# $$
# $$
# 11.5\mathrm{V} - 9.769\mathrm{V} = 1.731\mathrm{V}
# $$
#
# Es können sich auch zusätlich Fehler und Ungenauigkeiten der Messwerte eingeschhlichen haben, welche mit der Ungenauigkeit der Bauteile oder menschlichen Fehlern begründbar sind. Leider ist dies schlecht nachzuvollziehen, da dies nicht unsere Messwerte sind.
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.4: Impedanzwandlung
#
#  * Ergänzen Sie einen Impedanzwandler am Ausgang Ihrer Schaltung.
#  * Überprüfen Sie die Funktionsweise des Impedanzwandlers, indem Sie einen Lastwiderstand jeweils vor und hinter dem Impedanzwandler platzieren und den sich ggf. einstellenden Spannungseinbruch beobachten.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# In diesem Aufbau soll nun vor Aufgabe 1.3 ein Impedanzwandler geschaltet werden, welcher aus einem rückgekoppelten OPV besteht. Die Erwartung ist, dass der OPV jetzt als Buffer dient und das Signal des Offsets stabiler macht und das Rauschen reduziert. Zusätzlich sollte jetzt ein Lastwiderstand vor dem Impedanzwandler  geschaltet werden, welcher den Vorteil des Buffers wieder teilweise zerstören und die Ausgangsspannung senken kann. Platziert man ihn jedoch dahinter, bleibt das Ausgangssignal nahezu unverändert. Anschließend sollten wir noch die drei goldenen Regeln erklären, welche das Verhalten eines OPVs beschreiben.
# 1. Der OPV hat hohe Einganswiederstände
# 2. Der OPV hat eine niedrige Ausgangsimpedanz
# 3. Der OPV wählt seine Ausgangsspannung so, dass die Differenz der Eingangsspannungen verschwindet.
#
# ---

# %%
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("v1_4_1.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.28,         # vertikale Position
    "Abb.7 Signal Impedanzwandlung",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.28, 'Abb.7 Signal Impedanzwandlung')

# %% [markdown]
# **D I S K U S S I O N**
#
# Das Signalbild (Abb. 7) des nachgeschalteten Lastenwiderstands zeigt keinen Unterschied zu dem aus Aufgabe 1.3. Was die Funktionsweise des Impedanzwandlers bestätigt. Würde der Lastenwiderstand vor dem Impedanzwandler platziert werden, wäre ein deutlicher Einbruch der Amplitude und des Offset zu erkennen sein, leider lagen uns keine Messergebnisse dazu vor. Die Schaltung ist außerdem mittlerweile ziemlich groß und somit sehr fehleranfällig, was ebenfalls berücksichtigt werden sollte.
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 2: Nicht-invertierender Verstärker
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.1: Nicht-invertierender Verstärker
#
#  * Bauen Sie, unter Verwendung der Ihnen zur Verfügung stehenden Widerstände (in beiden Konfigurationsmöglichkeiten), einen nicht-invertierenden Verstärker auf.
#  * Vergewissern Sie sich von der Funktionsweise der Schaltung und verifizieren Sie den Verstärkungsfaktor.
#  * Beobachten Sie, was passiert, wenn das Ausgangssignal in die Sättigung geht.
#  * Beobachten Sie, was passiert, wenn Sie dem Eingangssignal einen DC-Offset hinzufügen.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# Bei dieser Aufgabe sollten wir einen nicht-invertierenden Verstärker untersuchen. Der hierfür benötigte Aufbau besteht aus einem OPV mit nachgeschaltetem Spannungsteiler mit $R_1 = 2{,}26\,\mathrm{k}\Omega$ und $R_2 = 1.15\mathrm{k\Omega}$. Die Rückkopplung des OPVs wird an das Ausgangssignal des Spannungsteilers gekoppelt (siehe Abb.8). Nun soll über den FG eine Frequenz von $\nu=1\mathrm{kHz}$ und eine Amplitude von $3V$ angelegt werden. Anschließend soll die Amplitude so verändert werden, dass das Ausgangssignal übersättigt ist und das Sinussignal abgeschnitten ist. Im letzten Teil des Versuchs soll jetzt ein DC-Offset am Eingang angelegt werden. Das Maximum des Ausgangsignals wird mithilfe der Goldenen Regel wievolgt berechnet.
#
#
# $$
# U_- = U_{out} \frac{R_2}{R_1+ R_2}
# $$
# $$
# U_- =U_+=U_{in}
# $$
# $$
# U_{out}=U_{in}(1+\frac{R_1}{R_2})=3\mathrm{V}(1+\frac{2.26\mathrm{k\Omega}}{1.15\mathrm{k\Omega}})\approx 8.9\mathrm{V}
# $$
#
# ---

# %%
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("A2_1.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.09,         # vertikale Position
    "Abb.8 Nicht-invertierender Verstärker",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.09, 'Abb.8 Nicht-invertierender Verstärker')

# %%
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("v2_1.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.29,         # vertikale Position
    "Abb.9 Nicht-ivertierender Verstärker",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.29, 'Abb.9 Nicht-ivertierender Verstärker')

# %%
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("v2_1_2.png")
plt.imshow(img)

plt.axis("off")

fig.text(
    0.5,          # horizontale Position (Mitte)
    0.29,         # vertikale Position
    "Abb.10 Nicht-ivertierender Verstärker Übersättigt",
    ha="center",
    fontsize=12
)
# Out:
# Text(0.5, 0.29, 'Abb.10 Nicht-ivertierender Verstärker Übersättigt')

# %% [markdown]
# **D I S K U S S I O N**
#
# In Abb.9 ist der erste Teil des Versuchs zu sehen. Hier wird ein Sinussignal eingegeben und es ist zu sehen, dass (CH1 = Eingangssignal) bei $\approx 3\mathrm{V}$ liegt und (CH2 = Ausgangssignal) bei den erwarteten $\approx 8.9\mathrm{V}$ liegt. In Abb. 10 ist die Übersättigung des Ausgangssignals zu sehen. Die Sättigung entsteht, weil der Operationsverstärker seine Ausgangsspannung nicht über die Versorgungsspannung hinaus anheben kann, sodass die Signalspitzen bei Erreichen der Versorgungsgrenze, bei $\approx 10 \mathrm{V}$, flach abgeschnitten werden. Zu dem DC‑Offset liegt uns leider kein Bild vor, jedoch ist anzunehmen, dass der Offset bei $3\mathrm{V}$ nur sehr gering ist. Auch bei dieser Aufgabe rechnen wir wieder mit Ungenauigkeiten der Bauteile und der Versuchsteilnehmer.
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.2: Verstärkungsgesetz
#
#  * Ersetzen Sie einen der Widerstände durch ein Potentiometer und messen Sie für fünf verschiedene Konfigurationen des Potentiometers den Verstärkungsfaktor.
#  * Überprüfen Sie den funktionalen Zusammenhang für den Verstärkungsfaktor $(1 + \frac{R_1}{R_2})$ durch eine entsprechende Modellanpassung.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# In diesem Versuch wird das Verstärkungsgesetz des nicht-invertierenden Operationsverstärkers experimentell überprüft. Dazu wird die Schaltung aus 2.1 erweitert, indem der Widerstand $R_1$ durch ein Potentiometer ersetzt wird. Dadurch kann man das Modell
#
# \begin{equation*}
# U_{\mathrm{out}} = U_{\mathrm{in}} \left(1 + \frac{R_1}{R_2}\right)
# \end{equation*}
#
# näher untersuchen.
#
# Die Spannungsverstärkung $\beta$ ist:
# \begin{equation*}
# \beta = 1 + \frac{R_1}{R_2}
# \end{equation*}
#
# Für ein sinusförmiges Eingangssignal ($\nu \approx 1\,\mathrm{kHz}$, Amplitude $2.8 \pm 0.2\,\mathrm{V}$) werden sechs verschiedene Verstärkungen im Bereich $U_{\mathrm{out}} = 3 \ldots 9\,\mathrm{V}$ eingestellt. Für jede Einstellung wird das Potentiometer angepasst, um andere Verstärungsfaktoren zu erhalten. $R_2 = 1.15 \, k\Omega $ bleibt dabei fest. Für beide Widerstände wird von einem relativen Fehler von 1 % ausgegangen. Auf $U_{\mathrm{in}}$ und $U_{\mathrm{out}}$ wird eine absolute Unsicherheit von 0.2 V angenommen.
#
# Ein- und Ausgangsspannung werden mit dem Oszilloskop gemessen. Aus den Messwerten werden die Größen $(U_{\mathrm{out}}/U_{\mathrm{in}},\, R_1/R_2)$ bestimmt und zur Überprüfung des Modells gefittet.
#
# ---

# %% [markdown]
# Auch hier werden Daten von anderen Gruppen verwendet:
#
# $$
# \begin{array}{c|c}
# R_1 \, [\mathrm{k \Omega}] & U_{\mathrm{out}} \, [\mathrm{V}] \\ \hline
#  0.22 & 3.0 \\
# 0.53 & 4.4 \\
# 1.01 & 5.2 \\
# 1.48 & 7.2 \\
# 1.83 & 7.4 \\
# 2.10 & 8.8 \\
# \end{array}
# $$
#
# Wenn man diese Daten auf das oben aufgeführte Modell fittet, erhält man:

# %%
from kafe2 import config, XYContainer, Fit, XYFit,  Plot
import numpy as np
from uncertainties import ufloat
import uncertainties.unumpy as unp
import matplotlib.pyplot as plt

# Widerstände in kOmega
R1 = .220
R2 = .530
R3 = 1.010
R4 = 1.480
R5 = 1.830
R6 = 2.100

R_1= np.array([R1, R2, R3, R4, R5, R6])
un_rel_R = 0.01
uR_1 = unp.uarray(R_1, un_rel_R * R_1)

# Ausgangsspannungen in V
U_1 = 3
U_2 = 4.4
U_3 = 5.2
U_4 = 7.2
U_5 = 7.4
U_6 = 8.8

U_out = np.array([U_1, U_2, U_3, U_4, U_5, U_6])
un_abs_U = 0.2
uU_out = unp.uarray(U_out, un_abs_U)

# Eingangsspannung in V
U_in = 2.8
uU_in = ufloat(U_in, un_abs_U)

# anderer Widerstand in kOmega:
R_2 = 1.15
uR_2 = ufloat(R_2, un_rel_R * R_2)

# Model fit

def amplification(R_1, R_2): 
    return U_in * (1 + R_1 / R_2)


xy_data = XYContainer(x_data=unp.nominal_values(uR_1), # R_2 werte als x-Achse
                      y_data=unp.nominal_values(uU_out))  # U_out werte als y-Achse

xy_data.add_error(
    axis='y', 
    err_val=unp.std_devs(uU_out)
)  
xy_data.add_error(
    axis='x', 
    err_val=unp.std_devs(uR_1)
) 

fit = Fit(data=xy_data, model_function=amplification)

# constrain R_2 and U_in
fit.add_parameter_constraint(name='R_2',   value=uR_2.nominal_value,   uncertainty=uR_2.std_dev)
#fit.add_parameter_constraint(name='U_in',   value=uU_in.nominal_value,   uncertainty=uU_in.std_dev)

fit.do_fit()

# plot the fit
plot = Plot(fit_objects=fit)

plot.x_label = '$R_1$ in k$\Omega$' 
plot.y_label = '$U_{out}$ in V'

plot.plot()
plt.show()

# %% [markdown]
# **D I S K U S S I O N**
#
# Vom dem Verlauf der Datenpunkte in der Graphik kann man sehen, dass die Annahme, dass $U_{\mathrm{out}}$ in $R_1$ linear ist, sehr wahrscheinlich korrekt ist. Allerdings ist der $\chi^2/ \alpha$ - Wert mit 6.041 etwas größer als 1. Das muss nicht auf ein unzureichendes Modell hinweisen. Da der Verlauf der Datenpunkte eher für dieses Modell sprechen, kann man davon ausgehen, dass die Unsicherheiten der Messung zu wenig konservativ abgeschätzt wurden. Da $R_1$ mit einem Multimeter sehr genau bestimmt werden konnte, wird davon ausgegangen, dass das Problem in der Abschätzung der Unsicherheit der Spannung $\Delta U = 0.2 V$ liegt. Diese sollte höher angenommen werden.
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.3: Zusatzaufgabe
#
# 🤓 **Diese Aufgaben sind nicht verpflichtend.** 🤓
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# #### Aufgabe 2.3a: Clamping-Dioden
#
#  * Bauen Sie die Schaltung aus Teilaufgabe 1 mit einem Verstärkungsfaktor von $3$ auf.
#  * Fügen Sie Ihrer Schaltung einen Ausgangswiderstand und zwei [Clamping-Dioden](https://www.electronics-tutorials.ws/diode/diode-clamping-circuit.html) hinzu
#  * Vergewissern Sie sich von der Funktion der Clamping-Dioden, indem Sie die Amplitude des Eingangssignals erhöhen, bis Sie den erwarteten Effekt beobachten.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 3: Invertierender Verstärker
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 3.1: Invertierender Verstärker
#
#  * Bauen Sie, unter Verwendung der Ihnen zur Verfügung stehenden Widerstände (in beiden Konfigurationsmöglichkeiten), einen invertierenden Verstärker auf.
#  * Vergewissern Sie sich von der Funktionsweise der Schaltung und verifizieren Sie den Verstärkungsfaktor.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# In diesem Versuch wird ein invertierender Operationsverstärker (OPV) aufgebaut (s. Abb. 3.1-1) und untersucht. Das Eingangssignal $U_{\mathrm{in}}$ wird über den Widerstand $R_1$ in den invertierenden Eingang eingespeist, während sich im Rückkopplungszweig der Widerstand $R_2$ befindet. Der nicht-invertierende Eingang ist mit Masse verbunden, sodass am invertierenden Eingang aufgrund der goldenen Regeln ebenfalls virtuelle Masse anliegt.
#
# Da kein Strom in den OPV fließt, ist der Strom durch beide Widerstände identisch. Mit dem ohmschen Gesetz ergibt sich:
# \begin{equation*}
# U_{\mathrm{in}} = R_1 I, \quad U_{\mathrm{out}} = -R_2 I
# \end{equation*}
# Daraus folgt für die Ausgangsspannung:
# \begin{equation*}
# U_{\mathrm{out}} = -U_{\mathrm{in}} \frac{R_2}{R_1}
# \end{equation*}
#
# Die Schaltung bewirkt somit eine Invertierung (Phasenverschiebung um $\pi$) und eine Verstärkung mit dem Faktor $\beta = \frac{R_2}{R_1}$.
#
# Für den Versuch werden Widerstände mit $R_1 = 1.15\,\mathrm{k\Omega}$ und $R_2 = 2.26 \,\mathrm{k\Omega}$ verwendet, sodass durch Tauschen der Widerstände zwei verschiedene Verstärkungsfaktoren realisiert werden können. Als $U_{\mathrm{in}}$ wird eine Sinusspannung ($\nu \approx 1\,\mathrm{kHz}$, Amplitude $3\,\mathrm{V}$) eingespeist.
#
# Es werden 2 unterschiedliche Verstärungsfaktoren $\beta$ erwartet:
#
# \begin{equation*}
# \beta_1 = \frac{R_1}{R_2} \approx 0.5 , \quad \beta_2 = \frac{R_2}{R_1} \approx 2
# \end{equation*}
#
# Zur Überprüfung werden Ein- und Ausgangsspannung mit dem Oszilloskop dargestellt und die Verstärkung für beide Widerstandskonfigurationen qualitativ bestimmt.
#
# ---

# %%
from os import getcwd
PWD = getcwd()

fig = plt.figure("demo", figsize=(10, 10))

img = mpimg.imread("Schaltbild31.png")
plt.imshow(img)

plt.axis("off")

# Bildbeschriftung
fig.text(
    0.5,          # horizontale Position (Mitte)
    0.24,         # vertikale Position
    "Abbildung 3.1-1: Schaltplan invertierender Verstärker",
    ha="center",
    fontsize=12
)

plt.show()

# %%
fig = plt.figure("demo", figsize=(10, 10))
img = mpimg.imread("v3_1_1.png")
plt.imshow(img)

plt.axis("off")

# Bildbeschriftung
fig.text(
    0.5,          # horizontale Position (Mitte)
    0.29,         # vertikale Position
    "Abbildung 3.1-2",
    ha="center",
    fontsize=12
)

plt.show()

# %%
fig = plt.figure("demo", figsize=(10, 10))
img = mpimg.imread("v3_1_2.png")
plt.imshow(img)

plt.axis("off")

# Bildbeschriftung
fig.text(
    0.5,          # horizontale Position (Mitte)
    0.29,         # vertikale Position
    "Abbildung 3.1-3",
    ha="center",
    fontsize=12
)

plt.show()

# %% [markdown]
# In den beiden Graphiken (Abb.3.1-2 und Abb. 3.1-3) sind $U_{\mathrm{in}}$ und $U_{\mathrm{out}}$ für beide Schaltungen dargestellt. Der Channel 1 (rot) misst die Eingangs-, Channel 2 (gelb) misst die Ausgangsspannung. Bei der oberen Schaltung wurde über $R_2$ rückgekoppelt, in der unteren Schaltung über $R_1$. In beiden Fällen wurde die Eingangsspannung invertiert. Auch die Verstärkungsfaktoren $\beta_1 = 0.5$ (Abb. 3.1-2) und $\beta_2 = 2$ (Abb. 3.1-3) stimmen ungefähr mit den Vorhersagen überein. In Graphik 1 halbiert sich die Eingangsspannung und in Graphik 2 verdoppelt sie sich.
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 3.2: Summierverstärker
#
#  * Bauen Sie einen Summierverstärker, der ein ${\pm}9\,\mathrm{V}$ Eingangssignal auf den Bereich $0\to3\,\mathrm{V}$ abbildet.
#  * Vergewissern Sie sich von der Funktion der Schaltung
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# In diesem Versuch wird ein invertierender Summierverstärker aufgebaut (s. Abb. 3.2-1) und untersucht. Zunächst wird die Wirkung einer einzelnen Eingangsspannung $U_1$ betrachtet. Diese wird über den Widerstand $R_1$ eingespeist, wobei der gesamte Strom über den Rückkopplungswiderstand $R_f$ abfließt. Es gilt:
# \begin{equation*}
# \frac{U_1}{R_1} = -\frac{U_{\mathrm{out}}}{R_f}
# \quad \Rightarrow \quad
# U_{\mathrm{out}} = -U_1 \frac{R_f}{R_1}
# \end{equation*}
#
# Werden zusätzlich mehrere Eingangsspannungen berücksichtigt, so addieren sich die Ströme am invertierenden Eingang. Für zwei Eingangsspannungen $U_1$ und $U_2$ folgt:
# \begin{equation*}
# \frac{U_1}{R_1} + \frac{U_2}{R_2} = -\frac{U_{\mathrm{out}}}{R_f}
# \quad \Rightarrow \quad
# U_{\mathrm{out}} = -\left( U_1 \frac{R_f}{R_1} + U_2 \frac{R_f}{R_2} \right)
# \end{equation*}
#
# Für den Versuch werden die Widerstände $R_1 = 6{,}81\,\mathrm{k\Omega}$, $R_2 = 9{,}09\,\mathrm{k\Omega}$ und $R_f = 1{,}15\,\mathrm{k\Omega}$ verwendet. An $R_1$ wird über einen Funktionsgenerator eine Sinusspannung ($\nu \approx 1\,\mathrm{kHz}$, Amplitude $9\,\mathrm{V}$) angelegt, während eine konstante Spannung von $12\,\mathrm{V}$ ($U_2$) über $R_2$ eingespeist wird. Die Eingangs- sowie Ausgangsspannung wird mit dem Oszilloskop dargestellt.
#
# Die angelegte Gleichspannung $U_2$ sollte nach obiger Formel ein Offset von $\approx - 1.5 \, V$ erzeugen und die sinusförmige Wechselspannung $U_1$ ein invertiertes Signal von $\approx 1.52 \, V$.
#
# ---

# %%
fig = plt.figure("demo", figsize=(10, 10))
img = mpimg.imread("Schaltbild32.png")
plt.imshow(img)

plt.axis("off")

# Bildbeschriftung
fig.text(
    0.5,          # horizontale Position (Mitte)
    0.29,         # vertikale Position
    "Abbildung 3.2-1: Summierverstärker",
    ha="center",
    fontsize=12
)

plt.show()

# %%
fig = plt.figure("demo", figsize=(10, 10))
img = mpimg.imread("v3_2.png")
plt.imshow(img)

plt.axis("off")
fig.text(
    0.5,          # horizontale Position (Mitte)
    0.29,         # vertikale Position
    "Abbildung 3.2-2",
    ha="center",
    fontsize=12
)

plt.show()

# %% [markdown]
# Die gemessene Eingangs- und Ausgangsspannung ist in Abb. 3.2-2 dargestellt. Die in der Versuchsbeschreibung beschriebene Erwartung des Ausgangssignals wurde beobachtet. Das Signal hat ein Offset von ungefähr - 1.5 V und wurde invertiert mit einer Amplitude von ungefähr 1.52 V.
#
# ---

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 3.3: Inverter
#
#  * Fügen Sie ihrer Schaltung einen Inverter zu.
#  * Vergewissern Sie sich von der Funktion der Schaltung.
#  * Diskutieren Sie den Unterschied zur Schaltung aus **Aufgabe 1**.
#
# </div>

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# In diesem Versuch wird die in Aufgabe 3.2 aufgebaute Summierverstärker-Schaltung um einen zusätzlichen Inverter ergänzt. Der Inverter hat eine Verstärkung von $\beta = -1$ (d.h. $R_1 = R_f$) und wird am Ausgang der bestehenden Schaltung angeschlossen.
#
# Der Summierverstärker aus Aufgabe 3.2 liefert eine invertierte, gewichtete Summe der Eingangsspannungen:
# \begin{equation*}
# V_{\mathrm{out'}} = -\left( V_1 \frac{R_f}{R_1} + V_2 \frac{R_f}{R_2} \right)
# \end{equation*}
#
# Durch den nachgeschalteten Inverter ergibt sich insgesamt:
# \begin{equation*}
# V_{\mathrm{out}} = - V_{\mathrm{out'}} =
# \left( V_1 \frac{R_f}{R_1} + V_2 \frac{R_f}{R_2} \right)
# \end{equation*}
#
# Die doppelte Invertierung hebt die Phasendrehung auf, sodass das Ausgangssignal nicht mehr invertiert ist. Gleichzeitig bleibt die gewichtete Skalierung der Eingangsspannungen erhalten. Die Schaltung wirkt damit ähnlich wie ein Spannungsteiler, jedoch aktiv und mit einstellbaren Verstärkungsfaktoren.
#
# Zur Überprüfung wird eine Sinusspannung ($\nu \approx 1\,\mathrm{kHz}$, Amplitude $9\,\mathrm{V}$) angelegt und Ein- sowie Ausgangsspannung mit dem Oszilloskop dargestellt. Es wird überprüft, dass keine Phaseninvertierung mehr vorliegt und die Amplitude entsprechend der Widerstandsverhältnisse skaliert ist.
#
# Im Unterschied zum passiven Spannungsteiler erfolgt die Spannungsanpassung hier aktiv über Operationsverstärker. Der OPV ist an einer Versorgungsspannung angeschlossen, was bedeutet, dass Leistung in das System eingespeist werden kann. Im Fall des passiven Spannungsteilers ist die Ausgangsspannung somit auf die Eingangsspannung begrenzt. Beim OPV ist der limitierende Faktor die Versorgungsspannung.
#
# ---

# %%
R = 1.15

import pandas as pd
import matplotlib.pyplot as plt

# load csv
df = pd.read_csv("33invertierer.csv")

# get data
time = df["Time"] * 1000    # in ms
ch1 = df["CH1"]
ch2 = df["CH2"]

plt.figure()
plt.plot(time, ch1, label="CH1 (Eingang)")
plt.plot(time, ch2, label="CH2 (Ausgang)")

plt.xlabel("Zeit (ms)")
plt.ylabel("Spannung (V)")
plt.title("Abb. 3.3: Messdaten Invertierverstärker")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# In Abb. 3.3 sind die erhobenen Daten dargestellt. Man kann deutlich erkennen, dass das Eingangssignal wie es in 3.2 dargestellt war, invertiert wurde. Das Offset und die Amplitude des Ausgangssignals aus 3.2 haben einen Vorzeichenwechsel bekommen. Somit konnte die Funktion der Schaltung bestätigt werden.
#
# Dieses Verhalten entspricht wie erwartet einem Spannungsteiler. Allerdings bietet diese Realisierung, wie in der Versuchsbeschreibung besprochen, mehr Möglichkeiten.
#
# ---

# %% [markdown]
# # Beurteilung

# %% [markdown]
#  * Beurteilen Sie diesen Versuch nach Abschluss der Auswertung.
#  * **Folgen Sie zur Beurteilung dieses Versuchs diesem [Link](https://www.empirio.de/s/BW9nuc3w0a)**.
#  * Beachten Sie, dass jede:r Studierende nur einmal pro Versuch eine Beurteilung abgeben kann.

# %% [markdown]
# **Lösung:**
#
# Fügen Sie Ihrem Protokoll einen Screenshot der letzten Informationsseite der oben verlinkten Beurteilung zu.
