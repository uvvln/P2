# %% [markdown]
# # Fakultät für Physik
#
# ## Physikalisches Praktikum P2 für Studierende der Physik
#
# Versuch P2-191, 192, 193 (Stand: **März 2025**)
#
# [Raum F1-15](https://labs.physik.kit.edu/img/Klassische-Praktika/Lageplan_P1P2.png)
#
#
#
# # Signalverarbeitung

# %% [markdown]
# Name: __________________ Vorname: __________________ E-Mail: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Name: __________________ Vorname: __________________ E-Mail: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Gruppennummer: _____
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
#
# Betreuer: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Versuch durchgeführt am: __________________

# %% [markdown]
# ---
#
# **Beanstandungen zu Protokoll Version _____:**
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# \end{split}
# %\text{\vspace{10cm}}
# \end{equation*}
#
# <br>
# Testiert am: __________________ Testat: __________________

# %% [markdown]
# # Durchführung
#
# **Detaillierte Kommentare zur Durchführung der Aufgaben finden Sie in der Datei [Signalverarbeitung_Hinweise.ipynb](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/Signalverarbeitung_Hinweise.ipynb)**

# %% [markdown]
# ## Aufgabe 1: Spannungsteiler und Impedanzwandler
#
# Bevor Sie die Aufgaben bearbeiten, müssen sie die Tastköpfe des Oszilloskops kalibrieren.

# %% [markdown]
# ### Aufgabe 1.1: Ohmscher Spannungsteiler
#
#  * Bauen Sie einen **Spannungsteiler** aus Widerständen auf, um eine Eingangsspannung von $\pm{}9V $ auf den Bereich von $\pm1,5V$ zu reduzieren
#  * Vergesissern Sie sich von der Funktionsweise dieser Schaltung
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 1.2: Frequenzkompensierter Spannugsteiler
#
#  * Bauen Sie zusätzlich zu dem Spannungsteiler einen kapazitiven Spannungsteiler in die Schaltung ein und überprüfen Sie seine funktionsweise.
#  * Stellen Sie den Trimmer-Kondensator so ein, dass Sie ein Rechteck-Signal möglichst verzerrungsfrei beobachten können.
#  * Vergewissern sie sich von der Funktionsweise dieser Schaltung
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 1.3: Offset-Addition
#
#  * Verwenden Sie einen weiteren Spannungsteiler, um die benötigte Offset-Sapnnung zu erzeugen, die das Ausgangssignal von $\pm1,5 \mathrm{V}$ auf den Bereich $0 \mathrm{V} \to 3 \mathrm{V}$ verschiebt.
#  * Fügen Sie der Schaltung eien Glättungskondensator hinzum, um Schwankungen in der Offsett-Spannung zu reduzieren.
#  * Vergewissern Sie sich von der Funktion der Schaltung
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 1.4: Impedanzwandlung
#
#  * Ergänzen Sie einen Impedanzwandler am Ausgang ihrer Schaltung.
#  * Überprüfen Sie die Funktionsweise des Impedanzwandlers, indem Sie einen Lastwiderstand jeweils vor und hinter dem Impedanzwandler platzieren und den daraus resultierenden Spannungseinbruch beobachten.

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ## Aufgabe 2: Nicht-invertierender Verstärker

# %% [markdown]
# ### Aufgabe 2.1: Nicht-invertierender Verstärker
#
#  * Bauen Sie einen nicht-invertierenden Verstärker auf. Verwenden Sie die ihnen dafür zur Vergügung gestellten Widerstände in beiden Konfigurationsmöglichkeiten
#  * Vergewissern Sie sich von der Funktionsweise dieser Schaltung und verifizieren Sie den Verstärkungsfaktor.
#  * Beobachten Sie, was passiert, wenn das Ausgangssignal in die Sättigung geht
#  * Beobachte Sie, was passiert, wenn Sie dem Eingangssignal einen DC-Offset hinzufügen
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 2.2: Verstärkungsgesetz
#
#  * Ersetzen Sie einen der Widerstände durch ein Potentiometer. Messen sie für fünf verschiedene Konfigurationen des Potentiometers den Verstärkungsfaktor
#  * Überprüfen Sie den Verstärkungsfaktor $(1 + \frac{R_1}{R_2})$ indem Sie eine Modellanpassung durchführen.
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 2.3: Clamping-Dioden
#
# **Diese Aufgabe ist nicht verpflichtend.**
#
#  * Bauen Sie die Schaltung aus Teilaufgabe 1 mit einem Verstärkungsfaktor von $3$ auf.
#  * Fügen sie ihrer Schaltung einen Ausgangswiderstand und zwei Clamping-Dioden hinzu
#  * Vergewissern Sie sich von der Funktion der Clamping-Dioden, indem Sie die Amplitude des Eingangssignals erhöhen, bis Sie den zugehörigen Effekt beobachten können.
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ## Aufgabe 3: Invertierender Verstärker

# %% [markdown]
# ### Aufgabe 3.1: Invertierender Verstärker
#
# ### Aufgabe 2.1: Nicht-invertierender Verstärker
#
#  * Bauen Sie einen invertierenden Verstärker auf. Verwenden Sie die ihnen dafür zur Vergügung gestellten Widerstände in beiden Konfigurationsmöglichkeiten
#  * Vergewissern Sie sich von der Funktionsweise dieser Schaltung und verifizieren Sie den Verstärkungsfaktor.
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 3.2: Summierverstärker
#
#  * Bauen Sie einen Summierverstärker, welcher ein $\pm9 \mathrm{V}$ Eingangssignal auf den Bereich $0 \mathrm{V} \to 3 \mathrm{V}$ abbildet.
#  * Vergewissern Sie sich von der Funktion dieser Schaltung
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 3.3: Inverter
#
#  * Fügen Sie ihrer Schaltung einen Inverter hinzu
#  * Vergewissern Sie sich von der Funktion dieser Schaltung
#  * Diskutieren Sie den Unterschied zur Schaltung aus Aufgabe 1
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# # Beurteilung

# %% [markdown]
#  * Beurteilen Sie diesen Versuch nach Abschluss der Auswertung.
#  * **Folgen Sie zur Beurteilung dieses Versuchs diesem [Link](https://www.empirio.de/s/BW9nuc3w0a)**.
#  * Beachten Sie, dass jede:r Studierende nur einmal pro Versuch eine Beurteilung abgeben kann.

# %% [markdown]
# **Lösung:**
#
# Fügen Sie Ihrem Protokoll einen Screenshot der letzten Informationsseite der oben verlinkten Beurteilung zu.
