# %% [markdown]
# # Fakultät für Physik
#
# ## Physikalisches Praktikum P2 für Studierende der Physik
#
# Versuch P2-191, 192, 193 (Stand: **März 2025**)
#
# [Raum F1-15](https://labs.physik.kit.edu/img/Klassische-Praktika/Lageplan_P1P2.png)
#
#
#
# # Signalverarbeitung

# %% [markdown]
# Name: __________________ Vorname: __________________ E-Mail: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Name: __________________ Vorname: __________________ E-Mail: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Gruppennummer: _____
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
#
# Betreuer: __________________
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# \end{split}
# \end{equation*}
#
# Versuch durchgeführt am: __________________

# %% [markdown]
# ---
#
# **Beanstandungen zu Protokoll Version _____:**
#
# \begin{equation*}
# \begin{split}
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# &\\
# \end{split}
# %\text{\vspace{10cm}}
# \end{equation*}
#
# <br>
# Testiert am: __________________ Testat: __________________

# %% [markdown]
# # Durchführung
#
# **Detaillierte Kommentare zur Durchführung der Aufgaben finden Sie in der Datei [Signalverarbeitung_Hinweise.ipynb](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Signalverarbeitung/Signalverarbeitung_Hinweise.ipynb)**

# %% [markdown]
# ## Aufgabe 1: Spannungsteiler und Impedanzwandler
#
# Bevor Sie die Aufgaben bearbeiten, müssen sie die Tastköpfe des Oszilloskops kalibrieren.

# %% [markdown]
# ### Aufgabe 1.1: Spannungsteiler aus Widerständen
#
#  * Bauen Sie einen **Spannungsteiler** aus Widerständen auf, um eine Eingangsspannung von $\pm{}5V $ auf den Bereich von $\pm1,5V$ zu reduzieren und überprüfen Sie seine Funktionsweise.
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 1.2: Frequenzkompensierter Spannugsteiler
#
#  * Bauen Sie zusätzlich zu dem Spannungsteiler einen kapazitiven Spannungsteiler in die Schaltung ein und überprüfen Sie seine funktionsweise
#  * Kallibrieren Sie den kapazitiven Spannugnsteiler indem Sie den Trimmer-Kondensator anpassen um die Verzerrungen zu eliminieren.
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 1.3: Impedanzwandlung
#
#  * Fügen Sie einen OPV als Spannugnsfolger an den Ausgang des Spannungsteilers hinzu
#  * Vergewissern Sie sich von der Funktion des Impedanzwandlers, indem Sie die Effekte eines Lastwiderstandes vor und hinter dem Spannungfolger mit einem Oszilloksop beobachten.
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 1.4: Pegelanpassung
#
#  * Ergänzen Sie die Schaltung um einen weiteren Spannungsteiler, welcher eine geeignete Offset-Spannung herausgibt um das Signal aus dem Bereichh $\pm1,5V$ in den Bereich von $0V$ bis $3V$ zu verschieben.
#  * Fügen Sie der Schaltung einen Glättungs-Kondensator und einen Impedanzwandler hinzu und verbinden Sie die daraus hervorgehende Offset-Spannung mit dem Frequenzkompensierten Spannungsteiler
#  * Vergewissern Sie sich von der Funktion dieser Schaltung.

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ## Aufgabe 2: Nicht-invertierender Verstärker

# %% [markdown]
# ### Aufgabe 2.1: Nicht-invertierender Verstärker
#
#  * Bauen Sie einen nicht-invertierenden Verstärker, um ein Eingangssignal aus dem Bereich $\pm0,5V$ in den Bereich $\pm5V$ zu verstärken und vergewissern Sie sich von der Funktion dieser Schaltung.
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# **L Ö S U N G**
#
# *Fügen Sie numerische Berechnungen zur Lösung dieser Aufgabe hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument. Um Code-Fragmente und Skripte in [Python](https://www.python.org/), sowie ggf. bildliche Darstellungen direkt ins [Jupyter notebook](https://jupyter.org/) einzubinden verwandeln Sie diese Zelle in eine Code-Zelle. Fügen Sie ggf. weitere Code-Zellen zu.*
#
# ---

# %% [markdown]
# **D I S K U S S I O N**
#
# *Fügen Sie eine abschließende Diskussion und Bewertung Ihrer Lösung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 2.2:
#
#  * Fügen sie der vorherigen Schaltung weitere Verstärkungsfaktoren hinzu, die wahlweise ausgewählt werden können und vergewissern Sie
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ## Aufgabe 3: Komplexere Schaltungen

# %% [markdown]
# ### Aufgabe 3.1: Einweggleichrichter
#
#  * Bauen Sie einen **idealen Einweggleichrichter** auf und demonstrieren Sie seine Funktionsweise.
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 3.2: Generator für Drei- und Rechtecksignale
#
#  * Bauen Sie einen **Generator für Drei- und Rechtecksignale** auf und demonstrieren Sie seine Funktionsweise.
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# ### Aufgabe 3.3: Analoge Lösung einer Differentialgleichung 2. Ordnung
#
#  * Bauen Sie eine analoge Schaltung zur Lösung einer **Differentialgleichung 2. Ordnung** auf.
#
# ---

# %% [markdown]
# **V E R S U C H S B E S C H R E I B U N G**
#
# *Fügen Sie Ihre Versuchsbeschreibung hier ein. Löschen Sie hierzu diesen kursiv gestellten Text aus dem Dokument.*
#
# ---

# %% [markdown]
# # Beurteilung

# %% [markdown]
#  * Beurteilen Sie diesen Versuch nach Abschluss der Auswertung.
#  * **Folgen Sie zur Beurteilung dieses Versuchs diesem [Link](https://www.empirio.de/s/BW9nuc3w0a)**.
#  * Beachten Sie, dass jede:r Studierende nur einmal pro Versuch eine Beurteilung abgeben kann.

# %% [markdown]
# **Lösung:**
#
# Fügen Sie Ihrem Protokoll einen Screenshot der letzten Informationsseite der oben verlinkten Beurteilung zu.
