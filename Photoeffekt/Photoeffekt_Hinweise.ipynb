# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# # Dokumente zur Vorbereitung auf den Versuch
#
# </div>

# %% [markdown]
#  * [Photoelektrischer Effekt](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Photoeffekt/doc/Hinweise-Photoeffekt.md)
#  * [Experimentelle Aufbauten](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Photoeffekt/doc/Hinweise-Messanordnung.md)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# # Hinweise zum Versuch Photoeffekt
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 1: Grundlagen
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.1: Photoelektrischer Effekt (Demonstrationsversuch)
#
# </div>

# %% [markdown]
# 🔧 **Hinweise zum Ablauf:** 🔧
#
#  * 🔔 Bei diesem Versuchsteil handelt es sich um einen **Demonstrationsversuch, den alle Gruppen gemeinsam mit Ihrem:r Tutor:in durchführen**.
#  * Dabei sind **Sorgfalt und Experimentiergeschick** gefragt.
#  * Gehen Sie bei diesem Versuch wie folgt vor:
#     * Laden Sie Zn-Platte **positiv** auf und beobachten Sie das Elektrometer, wenn Sie die Zn-Platte mit der Hg-Dampflampe bestrahlen.
#     * Laden Sie die Zn-Platte **negativ** auf und beobachten Sie das Elektrometer, wenn Sie die Zn-Platte mit der Hg-Dampflampe bestrahlen.
#    * Laden Sie die Zn-Platte negativ auf und beobachten Sie das Elektrometer, wenn Sie die Zn-Platte mit der Hg-Dampflampe bestrahlen und **zusätzlich eine positiv geladene Elektrode** in die Nähe der Zn-Platte bringen.
#  * 🔔 Beachten Sie dabei die folgenden Hinweise:
#    * Eine sich mit der Zeit bildende Oxydschicht kann die Photoemission der Zn-Platte stark beeinträchtigen. **Polieren Sie die Zn-Platte daher vor Versuchsbeginn sorgfältig**.
#    * Laden Sie die Zn-Platte daraufhin mit einer Spannung von etwa $\pm2\,\mathrm{kV}$ auf. Sie können hierfür die grobe Skala auf der Hochspannungsquelle nutzen. Es geht in erster Linie darum, dass Sie **Ladung auf die Zn-Platte aufbringen**.
#    * ⚠️ Die Spannungsquelle besitzt einen hohen Innenwiderstand, so dass im Ernstfall nur sehr geringe Ströme fließen. Dieser Versuchsteil ist also nicht gefährlich für Sie.
#    * 💡 Der Ausschlag des Versoriums ist träge; er ändert sich daher nur sehr langsam. Es bietet sich an, dass Sie die Spannung am Drehregler **langsam nach oben regeln**, bis Sie mit dem Ausschlag des Versoriums zufrieden sind.
#    * 💡 Erfahrungsgemäß hält die Zn-Platte die aufgebrachte Ladung leicht **für mehrere Minuten**. Sie wird sich mit zunehmender Zeit jedoch aufgrund von Wechselwirkungen mit der Umgebung entladen. Wie schnell dies geschieht hängt von äußeren Bedingungen, wie der Luftfeuchte ab. Die Halbwertszeit für diesen Vorgang können Sie, wenn Sie möchten, mit Hilfe einer Messung ohne Einstrahlung der Hg-Lampe grob abschätzen.
#
# ---
#
# 🖥️ **Hinweise zur Auswertung:** 🖥️
#
#  * ✍🏻 **Protokollieren Sie:** ✍🏻
#     * Beschreiben Sie Ihre Beobachtungen.
#     * Es handelt sich, bei dem was Sie beobachten um ein **Quantenphänomen**! Sie können den Vorgang, wenn Sie möchten, mit Ihrem Mobiltelefon aufzeichnen.
#     * Erklären Sie alle Beobachtungen, die Sie bei diesem Versuch machen.
#     * Beziehen Sie hierzu die folgenden Fragen in Ihre Diskussion ein:
#        * Wie groß ist die **Austrittsarbeit $E_{A}$** eines Elektrons aus Zn (in $\mathrm{eV}$)?
#        * Welcher **Wellenlänge $\lambda_{A}$ des Lichts** entspricht dies (in $\mathrm{nm}$)?
#        * Wie vergleicht sich $\lambda_{A}$ mit dem [Spektrum der Hg-Lampe](https://de.wikipedia.org/wiki/Quecksilberdampflampe)?
#        * Wie sieht die Transmission bzw. Absorption von Licht in (gewöhnlichem) Glas aus?
#        * Welche Konsequenzen hat dies für den Versuchsaufbau, wenn Sie z.B. das Licht der Hg-Lampe durch eine Linse fokussieren wollten?
#        * Kann man diesen Versuch in einem geschlossenen Raum bei Tageslicht durchführen oder sollte man verdunkeln?

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 1.2: Charakterisierung der Auslesekette
#
# </div>

# %% [markdown]
# 🔧 **Hinweise zum Ablauf:** 🔧
#
#  * **Beschreiben Sie die Messanordnung** zur Auslese der Photodiode in eigenen Worten.
#  * Diskutieren Sie die **Notwendigkeit eines hohen Innenwiderstands $R_{i}$** der Messanordnung.
#  * Schätzen Sie $R_{i}$ ab:
#     * 🔔 Beachten Sie hierzu die Diskussion [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Photoeffekt/doc/Hinweise-Messanordnung.md).
#     * Verwenden den am Versuchplatz ausliegenden Kondensator mit einer Kapazität von $C=(4.7\pm0.05)\ \mathrm{nF}$.
#     * Zeichnen Sie den Entladevorgang über die Messanordnung auf und schätzen Sie geeignete Unsicherheiten für den *time stamp* $t$ und die Spannung $U_{a}$ der Messteihe ab.
#
# ---
#
# 🖥️ **Hinweise zur Auswertung:** 🖥️
#
#  * ✍🏻 **Protokollieren Sie:** ✍🏻
#     * Tragen Sie die Messpunkte $(U_{a}, t)$ geeignet auf und passen Sie an die Messpunkte ein Modell nach Gleichung **(1) [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Photoeffekt/doc/Hinweise-Messanordnung.md)** an.
#        * 💡 Es kann sein, dass es zusätzlich zum allgemeinen Trend zu einer Oszillation des Signals kommt. In diesem Fall können Sie Ihr Modell zur Anpassung an die Messpunkte entsprechend um einen $\sin(\,\cdot\,)$-Term erweitern.
#        * Geben Sie den $\chi^{2}$-Wert der Anpassung geteilt durch die Anzahl der Freiheitsgrade des Modells an und diskutieren Sie, wie gut das Modell die Daten beschreiben kann.
#        * 🔔 Gerade wenn Sie Oszillationen im Signalverlauf feststellen, kann es sehr wohl passieren, dass es Ihnen nicht gelingen wird, den Verlauf der Datenpunkte adäquat zu beschreiben. Diskutieren Sie in diesem Fall, den vermutlichen Ursprung der Oszillationen in Ihrem Protokoll und argumentieren Sie, warum diese keinen Einfluss auf die Bestimmung von $R_{i}$ haben sollten.
#        * 🔔 Erinnern Sie sich hierzu an Ihre Diskussion des [Grundversuchs Datenverarbeitung](https://gitlab.kit.edu/kit/etp-lehre/p1-praktikum/students/-/blob/main/Datenverarbeitung/README.md).
#     * Nehmen Sie aus der Anpassung eine Abschätzung für $R_{i}\pm\Delta R_{i}$ vor.
#     * Alternativ dürfen Sie $R_{i}\pm\Delta R_{i}$ aus der Aufnahme von zwei Messpunkten mit entsprechend abgeschätzten Unsicherheiten abschätzen, wie [hier](https://gitlab.kit.edu/kit/etp-lehre/p1-praktikum/students/-/blob/main/Elektrische_Messtechnik/doc/Hinweise-Widerstaende.md#spannungsmessger%C3%A4te-mit-extrem-hohen-innenwiderst%C3%A4nden) diskutiert.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## Aufgabe 2: Bestimmung von $h$
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.1: Ladekurve als Funktion der Frequenz
#
# </div>

# %% [markdown]
# 🔧 **Hinweise zum Ablauf:** 🔧
#
#  * 🔔 Beachten Sie, dass die Hochdruck-Hg-Dampflampe ihr **Intensitätsmaximum erst ${\approx}10\,\mathrm{min}$ nach Inbetriebnahme** erreicht.
#  * 🔔 Achten Sie auf eine **zentrale und gute Ausleuchtung der Photozelle**.
#  * 🔔 Beachten Sie, dass die **ringförmige Anode** nicht durch das Licht der Hg-Dampflampe getroffen wird.
#  * Schließen Sie den ausliegenden Kondensator mit $4.7\,\mathrm{nF}$ parallel zum Signal der Photodiode.
#  * Schalten Sie Schritt für Schritt einen Filter nach dem anderen vor den Lichtschutzkollimator der Photozelle und zeichnen Sie die Ladekurve des Kondensators auf. Die Filter sind aufsteigend in $\lambda_{\mathrm{CWL}}^{(i)}$ montiert.
#  * Es empfiehlt sich eine Messteihe zwischen $5-10\,\mathrm{min}$. Sie sollten die Messreihe nicht beenden, bevor Sie das Plateau der Messung klar erkennen können.
#
# ---
#
# 🖥️ **Hinweise zur Auswertung:** 🖥️
#
#  * ✍🏻 **Protokollieren Sie:** ✍🏻
#     * Beschreiben Sie Ihr Vorgehen bei der Messung.
#     * Stellen Sie alle Messreihen in einem **gemeinsamen Diagramm** mit entsprechenden Labels oder entsprechender Legende dar.
#     * Wählen Sie die Ladekurve **für eine Wellenlänge** aus und passen Sie daran ein Modell sowohl nach Gleichung **(3)** als auch nach Gleichung **(4) [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Photoeffekt/doc/Hinweise-Photoeffekt.md)** an.
#        * Geben Sie jeweils den $\chi^{2}$-Wert der Anpassung geteilt durch die Anzahl der Freiheitsgrade des Modells an und diskutieren Sie, wie gut das jeweilige Modell die Daten beschrieben kann.
#        * **Wählen Sie das bessere Modell zur Beschreibung der Daten für alle Wellenlängen** aus und bestimmen Sie daraus $U_{\mathrm{Ph}}^{(i)}\pm\Delta U_{\mathrm{Ph}}^{(i)}$.
#     * Tragen Sie die gewonnen Werte für $U_{\mathrm{Ph}}\pm\Delta U_{\mathrm{Ph}}$ gegen $\nu_{\mathrm{CWL}}\pm \Delta\nu_{\mathrm{CWL}}$ auf.
#     * Passen ein Modell nach Gleichung **(2) [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Photoeffekt/doc/Hinweise-Photoeffekt.md)** an den Verlauf der sich ergebenden Datenpunkte an.
#     * Geben Sie den $\chi^{2}$-Wert der Anpassung geteilt durch die Anzahl der Freiheitsgrade des Modells an und diskutieren Sie, wie gut das Modell die Daten beschreiben kann.
#     * 🔔 Achten Sie, aus Gründen der **numersichen Stabilität der Anpassung** darauf, dass bei der Übergabe an den Algorithmus zur Anpassung für die Bestimmung von $h$, sowohl $U_{\mathrm{Ph}}^{(i)}$, als auch $\nu_{\mathrm{CWL}}^{(i)}$ numerische Werte $\mathcal{O}(1)$ annehmen.
#        * 💡 Sie erreichen dies z.B. indem Sie $U_{\mathrm{Ph}}^{(i)}$ in $\mathrm{eV}$ und $\nu_{\mathrm{CWL}}^{(i)}$ in $\mathrm{THz}$ angeben.
#     * 💡 Sowohl [$e=1.602176634\times10^{-19}\ \mathrm{C}$](https://de.wikipedia.org/wiki/Elementarladung) als auch [$c=2.99792458\times10^{8}\ \mathrm{m/s}$](https://de.wikipedia.org/wiki/Lichtgeschwindigkeit) sind SI-Einheiten definierende **Naturkonstanten, die ohne Unsicherheiten definiert sind**. Sie können diesen Umstand später berücksichtigen, um $h$ direkt zu bestimmen.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.2: Ladekurven als Funktion der Intensität
#
# </div>

# %% [markdown]
# 🔧 **Hinweise zum Ablauf:** 🔧
#
#  * Wählen Sie eine Wellenlänge $\lambda_{\mathrm{CWL}}$ aus, für die Sie jeweils eine **Ladekurve bei variierender Intensität des Lichts** aufzeichnen.
#  * Verwenden Sie hierzu ein am Versuch ausliegendes Paar von Polarisationsfiltern:
#     * 💡 Verwenden Sie einen Polarisationfilter als Polarisator, um linear polarisiertes Licht zu erzeugen.
#     * 💡 Verwenden Sie den anderen Polarisationsfilter als Analysator.
#     * 💡 Verwenden Sie z.B. **die folgenden Winkeleinstellungen**: $0^{\circ},\ 30^{\circ},\ 45^{\circ},\ 60^{\circ}$.
#
# ---
#
# 🖥️ **Hinweise zur Auswertung:** 🖥️
#
#  * ✍🏻 **Protokollieren Sie:** ✍🏻
#     * Beschreiben Sie Ihr Vorgehen bei der Messung.
#     * Stellen Sie alle Messreihen in einem **gemeinsamen Diagramm** mit entsprechenden Labels oder entsprechender Legende dar.
#     * **Bestimmen Sie aus den Ladekurven die $I_{\mathrm{Ph}}^{(i)}\pm\Delta I_{\mathrm{Ph}}^{(i)}$**, wie [hier](https://gitlab.kit.edu/kit/etp-lehre/p2-praktikum/students/-/blob/main/Photoeffekt/doc/Hinweise-Photoeffekt.md) beschrieben. Wählen Sie eine der beschriebenen Methoden aus.
#     * Stellen Sie $I_{\mathrm{Ph}}$ als Funktion der relativen Intensität des einfallenden Lichts dar und passen Sie ein geeigentes Modell an die Datenpunkte an.
#     * Geben Sie den $\chi^{2}$-Wert der Anpassung geteilt durch die Anzahl der Freiheitsgrade des Modells an und diskutieren Sie, wie gut das Modell die Daten beschreiben kann.

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Aufgabe 2.3: $I_{\mathrm{Ph}}$ als Funktion der Intensität
#
# </div>

# %% [markdown]
# 🔧 **Hinweise zum Ablauf:** 🔧
#
#  * Ersetzen Sie in der Messanordnung den Kondensator durch den ausliegenden Widerstand mit $R=1\,\mathrm{G\Omega}$, mit dem Sie die Photodiode kurzschließen.
#  * Bestimmen Sie $I_{\mathrm{Ph}}$ für die gleiche Wellenlänge, die Sie für **Aufgabe 2.2** ausgewählt haben.
#  * 🔔 Gehen Sie hierzu bei der Verwendung der Polarisaitonsfilter analog zu **Aufgabe 2.2** vor.
#
# ---
#
# 🖥️ **Hinweise zur Auswertung:** 🖥️
#
#  * ✍🏻 **Protokollieren Sie:** ✍🏻
#     * Fügen Sie die aufgezeichneten Messwerte der Darstellung aus **Aufgabe 2.2** zu. 💡 Es empfiehlt sich hierzu den Datenpunkten aus Darstellungsgründen einen kleinen *Offset* auf der $x$-Achse zu geben.
#     * Passen Sie ein geeigentes Modell an die Datenpunkte an.
#     * Geben Sie den $\chi^{2}$-Wert der Anpassung geteilt durch die Anzahl der Freiheitsgrade des Modells an und diskutieren Sie, wie gut das Modell die Daten beschreiben kann.
#     * Diskutieren Sie die Kompatibilität der Messungen aus **Aufgabe 2.2** und dieser Aufgabe.
